# %%
# Data evaluation of the questionnaire
# https://forms.gle/TiY3p9WSkGV8mNKk6

# importing packages
import pandas as pd
#from lxml import etree
import os.path, time

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import requests
#import json

import mlnotify 
# https://github.com/aporia-ai/mlnotify
# Use %%notify at beginning of cell


#inNotebook = True # change this to True if you use a notebook
#def nextplot():
#    if inNotebook:
#        plt.figure()  # this creates a new plot
#    else:
#        plt.clf()     # and this clears the current one

# !python --version
print('------------')
print("Pandas " + pd.__version__)
print("Numpy " + np.__version__)
print("Seaborn " + sns.__version__)
# Out:
# Python 3.7.6
# ------------
# Pandas 1.3.4
# Numpy 1.18.1
# Seaborn 0.11.2

# %%
# create single .csv-files per translated category
df_european_capital_cities_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_european_capital_cities_prep.csv', sep=';', encoding='utf-8')
df_lakes_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_lakes_prep.csv', sep=';', encoding='utf-8')
df_mountains_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_mountains_prep.csv', sep=';', encoding='utf-8')
df_european_countries_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_european_countries_prep.csv', sep=';', encoding='utf-8')
df_asian_countries_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_asian_countries_prep.csv', sep=';', encoding='utf-8')
df_continents_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_continents_prep.csv', sep=';', encoding='utf-8')
df_birds_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_birds_prep.csv', sep=';', encoding='utf-8')
df_african_animals_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_african_animals_prep.csv', sep=';', encoding='utf-8')
df_furniture_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_furniture_prep.csv', sep=';', encoding='utf-8')
df_vegetables_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_vegetables_prep.csv', sep=';', encoding='utf-8')
df_fast_food_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_fast_food_prep.csv', sep=';', encoding='utf-8')
df_european_landmarks_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_european_landmarks_prep.csv', sep=';', encoding='utf-8')
df_cities_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_cities_prep.csv', sep=';', encoding='utf-8')

# create single .csv-files per category that where not translated
df_nineties_movies_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_film90_prep.csv', sep=';', encoding='utf-8')
df_actors_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_actors_prep.csv', sep=';', encoding='utf-8')
df_music_genres_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_music_genres_prep.csv', sep=';', encoding='utf-8')
df_books_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_books_prep.csv', sep=';', encoding='utf-8')
df_authors_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_authors_prep.csv', sep=';', encoding='utf-8')
df_politicians_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_politicians_prep.csv', sep=';', encoding='utf-8')
df_us_presidents_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_potus_prep.csv', sep=';', encoding='utf-8')
df_dax_companies_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_dax_companies_prep.csv', sep=';', encoding='utf-8')
df_us_companies_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_us_companies_prep.csv', sep=';', encoding='utf-8')
df_us_tech_companies_prep = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/sv_us_tech_companies_prep.csv', sep=';', encoding='utf-8')

# %%
df_european_capital_cities_prep
# Out:
#     european_capital_cities  p_age p_gender           p_education p_country  \
# 0                    berlin     26     Male     Bachelor's degree   Germany
# 1                     paris     26     Male     Bachelor's degree   Germany
# 2                    london     26     Male     Bachelor's degree   Germany
# 3                 amsterdam     44     Male  Doctorate (e.g. PhD)   Germany
# 4                    berlin     44     Male  Doctorate (e.g. PhD)   Germany
# ..                      ...    ...      ...                   ...       ...
# 321                    rome     50   Female  Doctorate (e.g. PhD)   Germany
# 322                  london     50   Female  Doctorate (e.g. PhD)   Germany
# 323                  vienna     45   Female  Doctorate (e.g. PhD)   Germany
# 324                  berlin     45   Female  Doctorate (e.g. PhD)   Germany
# 325                  moscow     45   Female  Doctorate (e.g. PhD)   Germany
#
#      p_id                                    uri
# ...

# %%
df_european_landmarks_prep.head(50)
# Out:
#        european_landmarks  p_age p_gender                       p_education  \
# 0            eiffel tower     26     Male                 Bachelor's degree
# 1        brandenburg gate     26     Male                 Bachelor's degree
# 2               colosseum     26     Male                 Bachelor's degree
# 3            eiffel tower     44     Male              Doctorate (e.g. PhD)
# 4             towerbridge     44     Male              Doctorate (e.g. PhD)
# 5   leaning tower of pisa     44     Male              Doctorate (e.g. PhD)
# 6            eiffel tower     46     Male                 Bachelor's degree
# 7   leaning tower of pisa     46     Male                 Bachelor's degree
# 8              stonehenge     46     Male                 Bachelor's degree
# 9            eiffel tower     28     Male                   Master's degree
# 10       brandenburg gate     28     Male                   Master's degree
# ...
