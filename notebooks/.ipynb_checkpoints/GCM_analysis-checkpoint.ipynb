# %% [markdown]
# # Analyse Graph Centrality Measures (GCM) on DBpedia data

# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import statistics
import collections
#import danker # https://github.com/athalhammer/danker
from scipy import stats
from scipy.stats import kstest

from urllib import parse
from sklearn import linear_model
from sklearn import preprocessing
#from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.miscmodels.ordinal_model import OrderedModel

import mlnotify 
# https://github.com/aporia-ai/mlnotify
# Use %%notify at beginning of cell

import os.path, time
# Use %%time at beginning of cell

print('------------')
# !python --version
print("Pandas " + pd.__version__)
print("Numpy " + np.__version__)
print("Seaborn " + sns.__version__)
#print("Networkx " + nx.__version__)
print('------------')
print("All packages loaded and ready to roll :-)")
# Out:
# ------------
# Python 3.7.6
# Pandas 1.3.4
# Numpy 1.18.1
# Seaborn 0.11.2
# ------------
# All packages loaded and ready to roll :-)

# %%
# Load GCM data

# NetworkX
df_nx_gcm = pd.read_csv('../data/gcm_computed/nx-gcm.csv')

# iGraph
df_ig_gcm = pd.read_csv('../data/gcm_computed/ig-gcm.csv')

# %%
# Standardize GCMs
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

scaler = preprocessing.StandardScaler()

df_ig_gcm_scaled = df_ig_gcm.copy()
df_ig_gcm_scaled[['degree', 'eigenvector', 'pagerank']] = scaler.fit_transform(df_ig_gcm[['degree', 'eigenvector', 'pagerank']])
df_ig_gcm_scaled.head()
# Out:
#                                             resource       degree  \
# 0  http://dbpedia.org/resource/Billy_Coggins__Car...    -0.005582
# 1          http://dbpedia.org/ontology/CareerStation  2351.421216
# 2  http://dbpedia.org/resource/News_Patrol__A2Z_N...     0.003101
# 3  http://dbpedia.org/resource/ZOE_Broadcasting_N...     0.019019
# 4              http://dbpedia.org/resource/Yu_Yongfu    -0.001241
#
#    eigenvector     pagerank
# 0     1.346159    -0.004504
# 1  2138.166451  2029.349468
# 2    -0.331647    -0.000453
# 3    -0.331645     0.011483
# 4    -0.331641    -0.001202

# %%
print("Data types:")
print(df_ig_gcm.dtypes)
print('------------------------')
print("Memory usage:")
print(df_ig_gcm.memory_usage(deep=True))
print('------------------------')
print("Dataframe shape is {}".format(df_ig_gcm.shape))

print("========================")

print("Degree Centrality Kurtosis: %s" % stats.kurtosis(df_ig_gcm['degree']))
print("Degree Centrality Skewness: %s" % stats.skew(df_ig_gcm['degree']))
print('------------------------')
print("Eigenvector Centrality Kurtosis: %s" % stats.kurtosis(df_ig_gcm['eigenvector']))
print("Eigenvector Centrality Skewness: %s" % stats.skew(df_ig_gcm['eigenvector']))
print('------------------------')
print("PageRank Kurtosis: %s" % stats.kurtosis(df_ig_gcm['pagerank']))
print("PageRank Skewness: %s" % stats.skew(df_ig_gcm['pagerank']))
# Out:
# Data types:
# resource        object
# degree           int64
# eigenvector    float64
# pagerank       float64
# dtype: object
# ------------------------
# Memory usage:
# Index                128
# resource       964958363
# degree          65946664
# eigenvector     65946664
# pagerank        65946664
# dtype: int64
# ------------------------
# Dataframe shape is (8243333, 4)
# ========================
# Degree Centrality Kurtosis: 3845700.692636409
# Degree Centrality Skewness: 1758.6476950353158
# ------------------------
# Eigenvector Centrality Kurtosis: 2535495.292056733
# Eigenvector Centrality Skewness: 1186.2822293812544
# ------------------------
# PageRank Kurtosis: 2865512.8079392132
# PageRank Skewness: 1578.3902507400448

# %%
df_ig_gcm.describe()
# Out:
#              degree   eigenvector      pagerank
# count  8.243333e+06  8.243333e+06  8.243333e+06
# mean   6.857220e+00  1.550843e-04  1.213102e-07
# std    6.910175e+02  4.676179e-04  1.375352e-05
# min    1.000000e+00  0.000000e+00  2.435047e-08
# 25%    2.000000e+00  1.842308e-11  5.151196e-08
# 50%    3.000000e+00  2.267567e-09  6.047217e-08
# 75%    5.000000e+00  8.826938e-08  8.760632e-08
# max    1.624880e+06  1.000000e+00  2.791082e-02

# %%
# (OLD) Method for splitting the resource to get resource/name (based of the URI) to match PageRank dataframe

def node_path (row):
    return parse.urlsplit(row['resource']).path.split('/', 1)[-1]

# %%
# Function for printing a GCMs mean, stdev, as well as the max and min node

def gcmStats(data_frame, gcm_string):
    df_gcm = data_frame.copy()
    gcm_col = gcm_string
    gcm_top = df_gcm.sort_values(by=[gcm_col], ascending=False)
    gcm_low = df_gcm.sort_values(by=[gcm_col])

    print(gcm_col.upper()," CENTRALITY")
    print("==========================")
    print("The mean degree centrality is {}, with stdev {}".format(np.nanmean(df_gcm[gcm_col].values), np.nanstd(df_gcm[gcm_col].values)))#, statistics.stdev(degreesDC)))
    print("The maximum node is {} - with value {}".format(gcm_top['resource'].iat[0], gcm_top[gcm_col].iat[0]))
    print("The minimum node is {} - with value {}".format(gcm_low['resource'].iat[0], gcm_low[gcm_col].iat[0]))

# %%
gcmStats(df_ig_gcm, 'degree')
# Out:
# DEGREE  CENTRALITY
# ==========================
# The mean degree centrality is 6.857219525160515, with stdev 691.0174712767385
# The maximum node is http://dbpedia.org/ontology/CareerStation - with value 1624880
# The minimum node is http://dbpedia.org/resource/Robert_Dalrymple_Ross - with value 1

# %%
gcmStats(df_ig_gcm, 'eigenvector')
# Out:
# EIGENVECTOR  CENTRALITY
# ==========================
# The mean degree centrality is 0.00015508427622203387, with stdev 0.0004676179048092296
# The maximum node is http://dbpedia.org/ontology/CareerStation - with value 1.0
# The minimum node is http://dbpedia.org/resource/705_Erminia__Beltasteroid-stub__1 - with value 0.0

# %%
gcmStats(df_ig_gcm, 'pagerank')
# Out:
# PAGERANK  CENTRALITY
# ==========================
# The mean degree centrality is 1.213101545212344e-07, with stdev 1.3753518418526512e-05
# The maximum node is http://dbpedia.org/ontology/CareerStation - with value 0.0279108165979626
# The minimum node is http://dbpedia.org/resource/Rush_Tower,_Missouri - with value 2.4350470029608183e-08

# %% [markdown]
# ## Test on normal distribution
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html

# %%
def normDist(cat_gcm_data):
    df_gcm = cat_gcm_data.copy()
    
    print("Normal distribution for Degree Centrality")
    print('----------------------')
    print(stats.normaltest(df_gcm['degree']))
    print(kstest(df_gcm['degree'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality
    
    print('======================')
    
    print("Normal distribution for Eigenvector Centrality")
    print('----------------------')
    print(stats.normaltest(df_gcm['eigenvector']))
    print(kstest(df_gcm['eigenvector'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality
  
    print('======================')

    print("Normal distribution for PageRank")
    print('----------------------')
    print(stats.normaltest(df_gcm['pagerank']))
    print(kstest(df_gcm['pagerank'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

# %%
print("Normal distribution for Degree Centrality")
print('======================')
print('NetworkX')
print(stats.normaltest(df_nx_gcm['degree']))
print(kstest(df_nx_gcm['degree'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

print('----------------------')
print('iGraph')
print(stats.normaltest(df_ig_gcm['degree']))
print(kstest(df_ig_gcm['degree'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

#Normal distribution for Degree Centrality
#======================
#NetworkX
#NormaltestResult(statistic=69557965.55953461, pvalue=0.0)
#KstestResult(statistic=0.5000000483957555, pvalue=0.0) [Kolmogorov-Smirnov-Test]
#----------------------
#iGraph
#NormaltestResult(statistic=69557965.55953465, pvalue=0.0)
#KstestResult(statistic=0.8413447460685429, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %%
print("Normal distribution for Eigenvector Centrality")
print('======================')
print('NetworkX')
print("Not computed in NetworkX")

print('----------------------')
print('iGraph')
print(stats.normaltest(df_ig_gcm['eigenvector']))
print(kstest(df_ig_gcm['eigenvector'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

#Normal distribution for Eigenvector Centrality
#======================
#NetworkX
#Not computed in NetworkX
#----------------------
#iGraph
#NormaltestResult(statistic=63653056.418342546, pvalue=0.0)
#KstestResult(statistic=0.5, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %%
print("Normal distribution for PageRank")
print('======================')
print('NetworkX')
print(stats.normaltest(df_nx_gcm['pagerank']))
print(kstest(df_nx_gcm['pagerank'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

print('----------------------')
print('iGraph')
print(stats.normaltest(df_ig_gcm['pagerank']))
print(kstest(df_ig_gcm['pagerank'], 'norm'), '[Kolmogorov-Smirnov-Test]') # Kolmogorov-Smirnov-Test for normality

#Normal distribution for PageRank
#======================
#NetworkX
#NormaltestResult(statistic=68373823.03822671, pvalue=0.0)
#KstestResult(statistic=0.5000000072594243, pvalue=0.0) [Kolmogorov-Smirnov-Test]
#----------------------
#iGraph
#NormaltestResult(statistic=67903070.56349243, pvalue=0.0)
#KstestResult(statistic=0.500000009714432, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %% [markdown]
# ## Get DBpedia categories

# %%
# Load pre-queried (via queried web-interface) DBpedia categories
# https://dbpedia.org/sparql/

# 90s films from the aggregated Categories: 1990_films, 1991_films, 1992_films, ...
df_film90 = pd.read_csv("../data/sparql_cat_queries/sparql_90film.csv")
df_film90.rename(columns={"90film": "resource"}, inplace=True) #rename column to match PageRank dataframe

# actors from the "Occupation": "Actor"@en
df_actor = pd.read_csv("../data/sparql_cat_queries/sparql_actor.csv")
df_actor.rename(columns={"actor": "resource"}, inplace=True)

# Music Genre from the "Type": "dbo:MusicGenre"
df_musicGenre = pd.read_csv("../data/sparql_cat_queries/sparql_musicGenre.csv")
df_musicGenre.rename(columns={"mGenre": "resource"}, inplace=True)

# Books from the "Type":"dbo:book"
df_book = pd.read_csv("../data/sparql_cat_queries/sparql_book.csv")
df_book.rename(columns={"book": "resource"}, inplace=True)

# Book authors from the "Type": author UNION book dbo:author
df_bookAut = pd.read_csv("../data/sparql_cat_queries/sparql_bookAuthor.csv")
df_bookAut.rename(columns={"author": "resource"}, inplace=True)

# Politicians from the "Type": Person/Politician
df_pol = pd.read_csv("../data/sparql_cat_queries/sparql_politician.csv")
df_pol.rename(columns={"pol": "resource"}, inplace=True)

# POTUS from the "Category": Presidents_of_the_United_States
df_potus = pd.read_csv("../data/sparql_cat_queries/sparql_potus.csv")
df_potus.rename(columns={"potus": "resource"}, inplace=True)

# Cities from the "Category": "dbo:City"
df_city = pd.read_csv("../data/sparql_cat_queries/sparql_city.csv")
df_city.rename(columns={"city": "resource"}, inplace=True)

# Lakes from the "Category": "dbo:Lake"
df_lake = pd.read_csv("../data/sparql_cat_queries/sparql_lake.csv")
df_lake.rename(columns={"lake": "resource"}, inplace=True)

# Mountains from the "Category": "dbo:Mountain"
df_mountain = pd.read_csv("../data/sparql_cat_queries/sparql_mountain.csv")
df_mountain.rename(columns={"mount": "resource"}, inplace=True)

# EU capitals from the "Category": Capitals_in_Europe
df_euCap = pd.read_csv("../data/sparql_cat_queries/sparql_euCap.csv")
df_euCap.rename(columns={"euCap": "resource"}, inplace=True)

# EU countries from the "Category": Countries_in_Europe
df_euCou = pd.read_csv("../data/sparql_cat_queries/sparql_euCountry.csv")
df_euCou.rename(columns={"euCountry": "resource"}, inplace=True)

# Asian countries from the "Category": "dbc:Countries_in_Asia", "dbc:East_Asian_countries" and "dbc:Central_Asian_countries"
df_asCou = pd.read_csv("../data/sparql_cat_queries/sparql_asCountry.csv")
df_asCou.rename(columns={"asCountry": "resource"}, inplace=True)

# Continents from the "Category": "dbo:Continents"
df_continent = pd.read_csv("../data/sparql_cat_queries/sparql_continent.csv")
df_continent.rename(columns={"conti": "resource"}, inplace=True)

# Birds from the "Class": "dbr:Bird"
df_bird = pd.read_csv("../data/sparql_cat_queries/sparql_bird.csv")
df_bird.rename(columns={"bird": "resource"}, inplace=True)

# African animals from the "Category": "dbc:Vertebrates_of_Africa"
df_africanAnimal = pd.read_csv("../data/sparql_cat_queries/sparql_africanAnimal.csv")
df_africanAnimal.rename(columns={"afrAnimal": "resource"}, inplace=True)

# Furniture from the "Category": "dbc:Furniture"
df_furniture = pd.read_csv("../data/sparql_cat_queries/sparql_furniture.csv")
df_furniture.rename(columns={"fur": "resource"}, inplace=True)

# Furniture from the "Category": "dbc:Vegetables"
df_vegetable = pd.read_csv("../data/sparql_cat_queries/sparql_vegetable.csv")
df_vegetable.rename(columns={"veg": "resource"}, inplace=True)

# Types of fast food from the "Category": "dbc:Fast_food"
df_fastFood = pd.read_csv("../data/sparql_cat_queries/sparql_fastfood.csv")
df_fastFood.rename(columns={"fastFood": "resource"}, inplace=True)

# European Landmark/Sight from multiple "Category": "dbc:Landmarks_in_x" with x being a country from europe
df_euSight = pd.read_csv("../data/sparql_cat_queries/sparql_euLandmark.csv")
df_euSight.rename(columns={"euroSight": "resource"}, inplace=True)

# DAX company from the "Type": "dbo:Company" and "dbp:tradedAs" -> "dbr:DAX"
df_daxCo = pd.read_csv("../data/sparql_cat_queries/sparql_daxCompany.csv")
df_daxCo.rename(columns={"DAXco": "resource"}, inplace=True)

# US company from ?
df_usCo = pd.read_csv("../data/sparql_cat_queries/sparql_usCompany.csv")
df_usCo.rename(columns={"usCo": "resource"}, inplace=True)

# US tech company from the "Category": "dbc:Technology_companies_of_the_United_States"
df_usTechCo = pd.read_csv("../data/sparql_cat_queries/sparql_usTechCompany.csv")
df_usTechCo.rename(columns={"usTech": "resource"}, inplace=True)

# %% [markdown]
# ## Correlation Coefficient

# %%
# Compute the Pearson Correlation coefficient between the GCMs:
  # https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html
    
print("Pearson correlation coefficient for ev-dg: ", np.corrcoef(df_ig_gcm.eigenvector, df_ig_gcm.degree))
print("Pearson correlation coefficient for pr-dg: ", np.corrcoef(df_ig_gcm.pagerank, df_ig_gcm.degree))
print("Pearson correlation coefficient for pr-ev: ", np.corrcoef(df_ig_gcm.pagerank, df_ig_gcm.eigenvector))
# Out:
# Pearson correlation coefficient for ev-dg:  [[1.         0.60861409]
#  [0.60861409 1.        ]]
# Pearson correlation coefficient for pr-dg:  [[1.         0.95806588]
#  [0.95806588 1.        ]]
# Pearson correlation coefficient for pr-ev:  [[1.         0.52535622]
#  [0.52535622 1.        ]]

# %%
# Compute the Spearman Correlation coefficient between the GCMs:
  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html
    
print("Spearman correlation coefficient for ev-dg: ", stats.spearmanr(df_ig_gcm.eigenvector, df_ig_gcm.degree))
print("Spearman correlation coefficient for pr-dg: ", stats.spearmanr(df_ig_gcm.pagerank, df_ig_gcm.degree))
print("Spearman correlation coefficient for pr-ev: ", stats.spearmanr(df_ig_gcm.pagerank, df_ig_gcm.eigenvector))
# Out:
# Spearman correlation coefficient for ev-dg:  SpearmanrResult(correlation=0.2778606212958277, pvalue=0.0)
# Spearman correlation coefficient for pr-dg:  SpearmanrResult(correlation=0.9179017133326755, pvalue=0.0)
# Spearman correlation coefficient for pr-ev:  SpearmanrResult(correlation=0.2038934617506263, pvalue=0.0)

# %%
# Compute the Spearman Correlation coefficient between the GCMs:
  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html

print("Spearman correlation coefficient for ev-dg: ", stats.spearmanr(euCap_resultNorm.eigenvector, euCap_resultNorm.degree))
print("Spearman correlation coefficient for pr-dg: ", stats.spearmanr(euCap_resultNorm.pagerank, euCap_resultNorm.degree))
print("Spearman correlation coefficient for pr-ev: ", stats.spearmanr(euCap_resultNorm.pagerank, euCap_resultNorm.eigenvector))
# Out:
# Spearman correlation coefficient for ev-dg:  SpearmanrResult(correlation=0.8525569879620934, pvalue=1.0625968137065881e-15)
# Spearman correlation coefficient for pr-dg:  SpearmanrResult(correlation=0.9992316229830103, pvalue=5.146852039163385e-72)
# Spearman correlation coefficient for pr-ev:  SpearmanrResult(correlation=0.8493127294459148, pvalue=1.7588068373809613e-15)

# %%
# Compute the Spearman Correlation coefficient between the GCMs:
  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html
    
print("Spearman correlation coefficient for ev-dg: ", stats.spearmanr(euCou_resultNorm.eigenvector, euCou_resultNorm.degree))
print("Spearman correlation coefficient for pr-dg: ", stats.spearmanr(euCou_resultNorm.pagerank, euCou_resultNorm.degree))
print("Spearman correlation coefficient for pr-ev: ", stats.spearmanr(euCou_resultNorm.pagerank, euCou_resultNorm.eigenvector))

# Compute the Pearson Correlation coefficient between the GCMs:
  # https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html
    
print("Pearson correlation coefficient for ev-dg: ", np.corrcoef(euCou_resultNorm.eigenvector, euCou_resultNorm.degree))
print("Pearson correlation coefficient for pr-dg: ", np.corrcoef(euCou_resultNorm.pagerank, euCou_resultNorm.degree))
print("Pearson correlation coefficient for pr-ev: ", np.corrcoef(euCou_resultNorm.pagerank, euCou_resultNorm.eigenvector))
# Out:
# Spearman correlation coefficient for ev-dg:  SpearmanrResult(correlation=0.6879638009049773, pvalue=2.4347443116862553e-08)
# Spearman correlation coefficient for pr-dg:  SpearmanrResult(correlation=0.9910407239819004, pvalue=1.6463808845045838e-44)
# Spearman correlation coefficient for pr-ev:  SpearmanrResult(correlation=0.711131221719457, pvalue=4.980930367745989e-09)
# Pearson correlation coefficient for ev-dg:  [[1.         0.49356228]
#  [0.49356228 1.        ]]
# Pearson correlation coefficient for pr-dg:  [[1.        0.9865149]
#  [0.9865149 1.       ]]
# Pearson correlation coefficient for pr-ev:  [[1.         0.48617954]
#  [0.48617954 1.        ]]

# %% [markdown]
# ## Analyse categories

# %%
# Function for standardized scaling and normalisation of GCM values
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

def scaler(data_frame):
    helper_df = data_frame.copy()
    to_scale = StandardScaler()

    helper_df[['degree', 'eigenvector', 'pagerank']] = to_scale.fit_transform(helper_df[['degree', 'eigenvector', 'pagerank']])
    return helper_df

#df_ig_gcm = scaler(df_ig_gcm)

# %%
# Function for merging the sparql category with GCM data

# Merge the queried category df to the GCM metrics based on <resource> with a left outer join
# (Keep every row in the category dataframe -> missing values get NaN)

def catMergerNorm(sparql_data, gcm_data):
    df_sparql = sparql_data.copy()
    df_gcm = gcm_data.copy()
    helper_df = pd.merge(df_sparql,
                 #df_gcm[['resource','degree','pagerank']],
                 df_gcm[['resource','degree', 'eigenvector', 'pagerank']],
                 on='resource', 
                 how='left')
    
    # scale and normalize the gcm metrics (same as scaler function)
    to_scale = preprocessing.StandardScaler()
    helper_df[['degree', 'eigenvector', 'pagerank']] = to_scale.fit_transform(helper_df[['degree', 'eigenvector', 'pagerank']])
    
    print("Dataframe merged with shape: {}".format(helper_df.shape))
    print('============================')

    nan_rows = helper_df.shape[0] - helper_df.dropna().shape[0] #return amount of rows containing NaN values
    print("Rows with NaN values dropped: {}".format(nan_rows) + " from {}".format(helper_df.shape[0]) + " => {}% ".format(round((nan_rows/helper_df.shape[0])*100, 2))) #return amount of rows containing NaN values
    helper_df = helper_df.dropna()
    
    return helper_df

def catMerger(sparql_data, gcm_data):
    df_sparql = sparql_data.copy()
    df_gcm = gcm_data.copy()
    helper_df = pd.merge(df_sparql,
                 #df_gcm[['resource','degree','pagerank']],
                 df_gcm[['resource','degree', 'eigenvector', 'pagerank']],
                 on='resource', 
                 how='left')
    
    # scale and normalize the gcm metrics (same as scaler function)
    #to_scale = preprocessing.StandardScaler()
    #helper_df[['degree', 'eigenvector', 'pagerank']] = to_scale.fit_transform(helper_df[['degree', 'eigenvector', 'pagerank']])
    
    print("Dataframe merged with shape: {}".format(helper_df.shape))
    print('============================')

    nan_rows = helper_df.shape[0] - helper_df.dropna().shape[0] #return amount of rows containing NaN values
    print("Rows with NaN values dropped: {}".format(nan_rows) + " from {}".format(helper_df.shape[0]) + " => {}% ".format(round((nan_rows/helper_df.shape[0])*100, 2))) #return amount of rows containing NaN values
    helper_df = helper_df.dropna()

    return helper_df

# %% [markdown]
# ### Kernel density estimate for each category

# %%
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html

def kdeplots(data_frame, plot_name):
    save_name = plot_name.replace(" ","_")
    df_plots = data_frame.copy()
    df_name = plot_name
    sns.kdeplot(df_plots.degree, bw_adjust=.25)#, log_scale=True)
    sns.kdeplot(df_plots.eigenvector, bw_adjust=.25)#, log_scale=True)
    sns.kdeplot(df_plots.pagerank, bw_adjust=.25)#, log_scale=True)
    plt.legend(title='GCMs', loc='upper right', labels=['degree', 'eigenvector', 'pagerank'])
    plt.title("KDE plot for {}".format(df_name), size=18)
    plt.ylabel("Density", fontsize=14,fontweight='bold', labelpad=15)
    plt.xlabel(plot_name, fontsize=14,fontweight='bold', labelpad=15)
    plt.tick_params(labelsize=14)
    
    plt.savefig("../plots/plots_kde/kde_"+save_name+".png", bbox_inches="tight")
    plt.show()

# %%
euCap_result = catMergerNorm(df_euCap, df_ig_gcm)
# Out:
# Dataframe merged with shape: (52, 5)
# ============================
# Rows with NaN values dropped: 0 from 52 => 0.0%

# %%
# Plot the kernel density estimate (KDE)
# -> method for visualizing the distribution of observations in a dataset, analagous to a histogram.
# KDE represents the data using a continuous probability density curve in one or more dimensions.
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html

sns.kdeplot(euCap_result.degree)
# Out:
# <AxesSubplot:xlabel='degree', ylabel='Density'>

# %%
sns.kdeplot(euCap_result.eigenvector)
# Out:
# <AxesSubplot:xlabel='eigenvector', ylabel='Density'>

# %%
sns.kdeplot(euCap_result.pagerank)#,log_scale=True)
# Out:
# <AxesSubplot:xlabel='pagerank', ylabel='Density'>

# %%
euCap_resultNorm = catMergerNorm(df_euCap, df_ig_gcm)

euCap_resultNorm.head()
# Out:
# Dataframe merged with shape: (52, 5)
# ============================
# Rows with NaN values dropped: 0 from 52 => 0.0%
#                                             resource  \
# 0  http://dbpedia.org/resource/European_Capital_o...
# 1              http://dbpedia.org/resource/Podgorica
# 2     http://dbpedia.org/resource/City_of_San_Marino
# 3              http://dbpedia.org/resource/Gibraltar
# 4  http://dbpedia.org/resource/European_Youth_Cap...
#
#                           name    degree  eigenvector  pagerank
# 0  European Capital of Culture -0.676715    -1.107239 -0.691501
# 1                    Podgorica -0.535232    -0.008673 -0.552313
# 2           City of San Marino -0.650080    -1.057383 -0.665622
# 3                    Gibraltar -0.518621    -0.821540 -0.515938
# 4       European Youth Capital -0.676429    -1.113411 -0.691367

# %%
kdeplots(euCap_resultNorm, 'European capital cities')

# %%
musicGenres_resultNorm = catMergerNorm(df_musicGenre, df_ig_gcm)

kdeplots(musicGenres_resultNorm, 'Music genres')
# Out:
# Dataframe merged with shape: (10000, 5)
# ============================
# Rows with NaN values dropped: 4210 from 10000 => 42.1%

# %%
potus_resultNorm = catMergerNorm(df_potus, df_ig_gcm)

kdeplots(potus_resultNorm, 'US presidents')
# Out:
# Dataframe merged with shape: (48, 5)
# ============================
# Rows with NaN values dropped: 1 from 48 => 2.08%

# %%
lakes_resultNorm = catMergerNorm(df_lake, df_ig_gcm)

kdeplots(lakes_resultNorm, 'Lakes')
# Out:
# Dataframe merged with shape: (10000, 5)
# ============================
# Rows with NaN values dropped: 665 from 10000 => 6.65%

# %%
mountains_resultNorm = catMergerNorm(df_mountain, df_ig_gcm)

kdeplots(mountains_resultNorm, 'Mountains')
# Out:
# Dataframe merged with shape: (10000, 5)
# ============================
# Rows with NaN values dropped: 935 from 10000 => 9.35%

# %%
euCou_resultNorm = catMergerNorm(df_euCou, df_ig_gcm)

kdeplots(euCou_resultNorm, 'European countries')
# Out:
# Dataframe merged with shape: (51, 5)
# ============================
# Rows with NaN values dropped: 0 from 51 => 0.0%

# %%
asCou_resultNorm = catMergerNorm(df_asCou, df_ig_gcm)

kdeplots(asCou_resultNorm, 'Asian countries')
# Out:
# Dataframe merged with shape: (60, 5)
# ============================
# Rows with NaN values dropped: 7 from 60 => 11.67%

# %%
africanAnimal_resultNorm = catMergerNorm(df_africanAnimal, df_ig_gcm)

kdeplots(africanAnimal_resultNorm, 'African Animal')
# Out:
# Dataframe merged with shape: (10000, 5)
# ============================
# Rows with NaN values dropped: 8628 from 10000 => 86.28%

# %%
continents_resultNorm = catMergerNorm(df_continent, df_ig_gcm)

kdeplots(continents_resultNorm, 'Continents')
# Out:
# Dataframe merged with shape: (20, 5)
# ============================
# Rows with NaN values dropped: 5 from 20 => 25.0%

# %%
vegetables_resultNorm = catMergerNorm(df_vegetable, df_ig_gcm)

kdeplots(vegetables_resultNorm, 'Vegetables')
# Out:
# Dataframe merged with shape: (3742, 5)
# ============================
# Rows with NaN values dropped: 1801 from 3742 => 48.13%

# %%
fastFood_resultNorm = catMergerNorm(df_fastFood, df_ig_gcm)

kdeplots(fastFood_resultNorm, 'Fast food')
# Out:
# Dataframe merged with shape: (4693, 5)
# ============================
# Rows with NaN values dropped: 1006 from 4693 => 21.44%

# %%
birds_resultNorm = catMergerNorm(df_bird, df_ig_gcm)

kdeplots(birds_resultNorm, 'Birds')
# Out:
# Dataframe merged with shape: (10000, 5)
# ============================
# Rows with NaN values dropped: 6677 from 10000 => 66.77%

# %% [markdown]
# ### Compare the top ranking results

# %%
# Load survey results per category

#sv_nineties_films = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_film90_impr.csv", sep=';')
#sv_actors = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_actors_impr.csv", sep=';')
sv_music_genres = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_music_genres_impr.csv', sep=';', encoding='utf-8')
#sv_books = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_books_impr.csv", sep=';')
#sv_bookAut = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_authors_impr.csv", sep=';')
#sv_politicians = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_politicians_impr.csv", sep=';')
sv_potus = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_potus_impr.csv', sep=';', encoding='utf-8')
#sv_cities = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_cities_impr.csv', sep=';', encoding='utf-8')
sv_lakes = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_lakes_impr.csv", sep=';')
sv_mountains = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/sv_mountains_prep.csv", sep=';')
sv_european_capital_cities = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_european_capital_cities_impr.csv', sep=';', encoding='utf-8')
sv_european_countries = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_european_countries_impr.csv', sep=';', encoding='utf-8')
sv_asian_countries = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_asian_countries_impr.csv", sep=';')
sv_continents = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_continents_impr.csv', sep=';', encoding='utf-8')
sv_birds = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_birds_impr.csv', sep=';', encoding='utf-8')
sv_african_animals = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_african_animals_impr.csv", sep=';')
#sv_furniture = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_furniture_impr.csv", sep=';')
sv_vegetables = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_vegetables_impr.csv', sep=';', encoding='utf-8')
sv_fastfood = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_fast_food_impr.csv", sep=';')
#sv_european_landmarks = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_european_landmarks_impr.csv", sep=';')
#sv_dax_companies = pd.read_csv("../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_dax_companies_impr.csv", sep=';')
#sv_us_companies = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_us_companies_impr.csv', sep=';', encoding="ISO-8859-1") # different encoding due to special character (é)
#sv_us_tech_companies = pd.read_csv('../data/survey_single_cat_files/sv_prep_uri/improved_uri/sv_us_tech_companies_impr.csv', sep=';', encoding='utf-8')

# %%
# Function for sorting the GCM-Category data
  # input parameters: 
    # cat_data_frame -> merged dataframe of GCM and categories (e.g. potus_resultNorm)
    # gcm_string -> string on which gcm data to sort (e.g. 'pagerank')
    # opt='p' -> option to toogle the sort between top number or percentage ('p' = percentage; 'n' = number)
    # lot_nr=5 -> the top results either in percentage or actual numbers

    
def sort_gcm_cat(cat_data_frame, gcm_string, lot_nr=5, opt='p'):
    sort_df = cat_data_frame.copy()
    gcm_name = gcm_string
    t = lot_nr
    
    sort_df = sort_df.sort_values(by=gcm_name, ascending=False)
    
    if opt == 'p':
        return_df = sort_df.head(int(len(sort_df)*(t/100)))
    elif opt == 'n':
        return_df = sort_df.head(t)

    return return_df

# %%
# Function for calculating P@k
  # input parameters: 
    # survey_data -> loaded survey data (e.g. sv_potus)
    # cat_gcm_data -> merged dataframe of GCM and categories (e.g. potus_resultNorm)
    # gcm_string -> string on which gcm data to sort (e.g. 'pagerank')
    # opt='p' -> option to toogle the sort between top number or percentage ('p' = percentage; 'n' = number)
    # lot_nr=5 -> the top results either in percentage or actual numbers (e.g. 10)

def precisionAtK(survey_data, cat_gcm_data, gcm_string, lot_nr=5, opt='p'): 
    # Prepare survey data
    df_survey = survey_data.copy()
    
    df_survey.rename(columns={"uri": "resource"}, inplace=True) #rename column to match GCM dataframe
    survey_count = df_survey['resource'].value_counts()#count how often an answer was given in the survey
    df_survey_counted = pd.DataFrame({'resource':survey_count.index, 'amount':survey_count.values})

    # Prepare GCM data
    df_cat_gcm = cat_gcm_data.copy()
    gcm_name = gcm_string
    t = lot_nr
    
    df_cat_gcm = df_cat_gcm.sort_values(by=gcm_name, ascending=False)
    if opt == 'p':
        df_cat_gcm = df_cat_gcm.head(int(len(df_cat_gcm)*(t/100)))
    elif opt == 'n':
        df_cat_gcm = df_cat_gcm.head(t)

    # Merge top t from the GCM into survey category based on the URI -> successful merges are hits
    df_survey_gcm = pd.merge(df_survey_counted,
                df_cat_gcm[['resource','name', 'degree','eigenvector','pagerank']],
                on='resource', 
                how='left')
    
    # Get rows that were not matched with the category and calculate P@k
    nan_rows = df_survey_gcm.shape[0] - df_survey_gcm.dropna().shape[0]
    hits = df_survey_gcm.shape[0]-nan_rows
    
    if opt == 'p':
        p_at_k = hits/df_cat_gcm.shape[0]
    elif opt == 'n':
        p_at_k = hits/t
    
    print("Precision at k={}".format(t) +" ({})".format(opt) + " for {}".format(gcm_name.upper()))
    print('-------------------------------------')
    print("Entries in the DBpedia category: {}".format(cat_gcm_data.shape[0]))
    print("DBpedia entries taken: top {}".format(df_cat_gcm.shape[0]))
    print("Entries in the gold standard: {}".format(df_survey_counted.shape[0]))
    print('-------------------------------------')
    print("HITS: {}".format(hits))
    print("P@{}".format(t) + ": {}".format(p_at_k))
    print('=====================================')
    
    return df_survey_gcm

# %%
n = 1 # percentage of top results

musicGenres_result_sort = musicGenres_resultNorm.sort_values(by='degree', ascending=False)
musicGenres_result_sort.head(int(len(musicGenres_result_sort)*(n/100)))
# Out:
#                                                resource  \
# 3408              http://dbpedia.org/resource/Pop_music
# 2577          http://dbpedia.org/resource/Country_music
# 1822       http://dbpedia.org/resource/Alternative_rock
# 2916             http://dbpedia.org/resource/Rock_music
# 4311          http://dbpedia.org/resource/Hip_hop_music
# 2756                   http://dbpedia.org/resource/Jazz
# 3742             http://dbpedia.org/resource/Indie_rock
# 2922        http://dbpedia.org/resource/Science_fiction
# 5859               http://dbpedia.org/resource/Pop_rock
# 7736       http://dbpedia.org/resource/Contemporary_R&B
# 531          http://dbpedia.org/resource/Single_(music)
# 3737              http://dbpedia.org/resource/Hard_rock
# 3441       http://dbpedia.org/resource/Rhythm_and_blues
# 3698             http://dbpedia.org/resource/Soul_music
# 2677             http://dbpedia.org/resource/Folk_music
# 5737             http://dbpedia.org/resource/Subsidiary
# 3422              http://dbpedia.org/resource/Punk_rock
# 2711      http://dbpedia.org/resource/Heavy_metal_music
# 2795                  http://dbpedia.org/resource/Manga
# 6713                http://dbpedia.org/resource/Fantasy
# 2626       http://dbpedia.org/resource/Electronic_music
# 549               http://dbpedia.org/resource/Synth-pop
# 3377         http://dbpedia.org/resource/New_wave_music
# 5443                  http://dbpedia.org/resource/J-pop
# 5286                 http://dbpedia.org/resource/Comedy
# 5629              http://dbpedia.org/resource/Dance-pop
# 5434     http://dbpedia.org/resource/Financial_services
# 2514                  http://dbpedia.org/resource/Blues
# 5287                  http://dbpedia.org/resource/Drama
# 2539           http://dbpedia.org/resource/Christianity
# 3416       http://dbpedia.org/resource/Progressive_rock
# 4623  http://dbpedia.org/resource/Nonprofit_organiza...
# 1881              http://dbpedia.org/resource/Folk_rock
# 4237        http://dbpedia.org/resource/Classical_music
# 200   http://dbpedia.org/resource/Drama_(film_and_te...
# 2685                   http://dbpedia.org/resource/Funk
# 2908     http://dbpedia.org/resource/Reality_television
# 5106              http://dbpedia.org/resource/Indie_pop
# 3636  http://dbpedia.org/resource/Children's_literature
# 2732            http://dbpedia.org/resource/House_music
# 4715                 http://dbpedia.org/resource/Retail
# 2969             http://dbpedia.org/resource/Talk_radio
# 3443          http://dbpedia.org/resource/Rock_and_roll
# 4699        http://dbpedia.org/resource/Mystery_fiction
# 2889          http://dbpedia.org/resource/Platform_game
# 5294                 http://dbpedia.org/resource/Sitcom
# 2911                 http://dbpedia.org/resource/Reggae
# 2729         http://dbpedia.org/resource/Horror_fiction
# 4239            http://dbpedia.org/resource/Dance_music
# 7884  http://dbpedia.org/resource/Adult_contemporary...
# 3420       http://dbpedia.org/resource/Psychedelic_rock
# 3096              http://dbpedia.org/resource/Post-punk
# 747            http://dbpedia.org/resource/Romance_film
# 4673             http://dbpedia.org/resource/Electropop
# 558        http://dbpedia.org/resource/Thriller_(genre)
# 1665             http://dbpedia.org/resource/Blues_rock
# 801             http://dbpedia.org/resource/Electronica
#
#                              name     degree  eigenvector   pagerank
# 3408                    Pop music  32.201888     0.037286  31.603269
# 2577                Country music  23.133426    -0.029161  23.206595
# 1822             Alternative rock  20.722094     0.005411  20.150214
# 2916                   Rock music  19.965306     0.012149  19.579307
# 4311                Hip hop music  18.453587    -0.004172  17.043364
# 2756                         Jazz  15.016511     0.000039  14.861902
# 3742                   Indie rock  12.334368    -0.009423  12.410688
# 2922              Science fiction  12.228641     0.006178  13.588646
# 5859                     Pop rock  12.134042     0.018349  11.701975
# 7736             Contemporary R&B  11.742665    -0.024771  10.720268
# 531                Single (music)  11.670325    -0.037709  11.095871
# 3737                    Hard rock  10.420142    -0.017677   9.550473
# 3441             Rhythm and blues   9.587305    -0.023769   8.901624
# 3698                   Soul music   9.578031    -0.024002   8.825146
# 2677                   Folk music   9.158830    -0.016739   9.507329
# 5737                   Subsidiary   8.555997     0.031069  10.124404
# 3422                    Punk rock   8.463253    -0.017253   8.311717
# 2711            Heavy metal music   7.240894    -0.022154   6.728153
# 2795                        Manga   7.177828    -0.008343   9.169399
# 6713                      Fantasy   6.879194     0.000417   7.535145
# 2626             Electronic music   6.552737    -0.019309   6.312217
# 549                     Synth-pop   6.007405    -0.028169   5.589187
# 3377               New wave music   5.912806     0.005985   5.441364
# 5443                        J-pop   5.727319    -0.030875   5.960802
# 5286                       Comedy   5.571510     0.002367   5.812814
# 5629                    Dance-pop   5.476912    -0.032206   5.107602
# 5434           Financial services   5.465782     0.033002   6.477234
# 2514                        Blues   5.436104    -0.029352   5.185603
# 5287                        Drama   5.365619     0.040334   5.455431
# 2539                 Christianity   5.343361     0.119610   5.807932
# 3416             Progressive rock   5.233924    -0.022058   5.065923
# 4623       Nonprofit organization   5.096663     0.170903   7.567563
# 1881                    Folk rock   4.938999    -0.028363   4.854909
# 4237              Classical music   4.898192     0.009477   5.268666
# 200   Drama (film and television)   4.883353    -0.000945   4.635090
# 2685                         Funk   4.799884    -0.030529   4.370521
# 2908           Reality television   4.755367     0.000839   5.454911
# 5106                    Indie pop   4.573590    -0.028500   4.608536
# 3636        Children's literature   4.480846    -0.000732   5.112182
# 2732                  House music   4.280520     0.000865   4.058736
# 4715                       Retail   4.004144     0.019247   5.072061
# 2969                   Talk radio   3.827932    -0.002506   4.521708
# 3443                Rock and roll   3.785270    -0.031472   3.550688
# 4699              Mystery fiction   3.738898    -0.004002   3.833238
# 2889                Platform game   3.694381    -0.009527   3.205466
# 5294                       Sitcom   3.648009     0.045370   3.477292
# 2911                       Reggae   3.560830    -0.030509   3.540106
# 2729               Horror fiction   3.557120    -0.004660   3.883288
# 4239                  Dance music   3.518168    -0.030732   3.384047
# 7884     Adult contemporary music   3.471796    -0.034986   4.291220
# 3420             Psychedelic rock   3.460667    -0.019562   3.294603
# 3096                    Post-punk   3.440264    -0.027404   3.243240
# 747                  Romance film   3.403166     0.000454   3.214597
# 4673                   Electropop   3.401311    -0.034264   3.232946
# 558              Thriller (genre)   3.356794    -0.003019   3.453980
# 1665                   Blues rock   3.277035    -0.032577   2.961667
# 801                   Electronica   3.245502    -0.029180   3.154195

# %% [markdown]
# ### Music genres

# %%
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 1
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 5
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 10
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 6
# P@10: 0.6
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 57
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 19
# P@1: 0.3333333333333333
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 115
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 21
# P@2: 0.1826086956521739
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 289
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 29
# P@5: 0.10034602076124567
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 579
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 30
# P@10: 0.05181347150259067
# =====================================
#                                              resource  amount  \
# 0              http://dbpedia.org/resource/Rock_music      56
# 1               http://dbpedia.org/resource/Pop_music      51
# 2           http://dbpedia.org/resource/Hip_hop_music      51
# 3                    http://dbpedia.org/resource/Jazz      27
# 4         http://dbpedia.org/resource/Classical_music      26
# 5       http://dbpedia.org/resource/Heavy_metal_music      20
# 6                  http://dbpedia.org/resource/Techno      20
# 7             http://dbpedia.org/resource/House_music       8
# 8        http://dbpedia.org/resource/Rhythm_and_blues       7
# 9              http://dbpedia.org/resource/Indie_rock       6
# 10              http://dbpedia.org/resource/Punk_rock       6
# 11            http://dbpedia.org/resource/Swing_music       4
# 12        http://dbpedia.org/resource/Electro_(music)       3
# 13          http://dbpedia.org/resource/Country_music       3
# 14                   http://dbpedia.org/resource/Funk       3
# 15             http://dbpedia.org/resource/Soul_music       3
# 16                  http://dbpedia.org/resource/Blues       3
# 17       http://dbpedia.org/resource/Psychedelic_rock       3
# 18              http://dbpedia.org/resource/Hardstyle       2
# 19         http://dbpedia.org/resource/Schlager_music       2
# 20           http://dbpedia.org/resource/Echo_Klassik       2
# 21           http://dbpedia.org/resource/Trance_music       2
# 22              http://dbpedia.org/resource/Indie_pop       1
# 23           http://dbpedia.org/resource/Black_pepper       1
# 24       http://dbpedia.org/resource/Mushroom_Records       1
# 25                 http://dbpedia.org/resource/Carrot       1
# 26        http://dbpedia.org/resource/Romance_(music)       1
# 27                http://dbpedia.org/resource/Baroque       1
# 28  http://dbpedia.org/resource/Electronic_dance_m...       1
# 29             http://dbpedia.org/resource/Conducting       1
# 30              http://dbpedia.org/resource/Hard_rock       1
# 31             http://dbpedia.org/resource/Trap_music       1
# 32                  http://dbpedia.org/resource/Disco       1
# 33         http://dbpedia.org/resource/German_hip_hop       1
# 34        http://dbpedia.org/resource/Musical_theatre       1
# 35              http://dbpedia.org/resource/Dance-pop       1
# 36          http://dbpedia.org/resource/Rock_and_roll       1
# 37                  http://dbpedia.org/resource/Opera       1
#
#                       name     degree  eigenvector   pagerank
# 0               Rock music  19.965306     0.012149  19.579307
# 1                Pop music  32.201888     0.037286  31.603269
# 2            Hip hop music  18.453587    -0.004172  17.043364
# 3                     Jazz  15.016511     0.000039  14.861902
# 4          Classical music   4.898192     0.009477   5.268666
# 5        Heavy metal music   7.240894    -0.022154   6.728153
# 6                   Techno   1.405470    -0.034476   1.337463
# 7              House music   4.280520     0.000865   4.058736
# 8         Rhythm and blues   9.587305    -0.023769   8.901624
# 9               Indie rock  12.334368    -0.009423  12.410688
# 10               Punk rock   8.463253    -0.017253   8.311717
# 11             Swing music   0.728443    -0.037940   0.644756
# 12         Electro (music)   1.119820    -0.007088   1.040245
# 13           Country music  23.133426    -0.029161  23.206595
# 14                    Funk   4.799884    -0.030529   4.370521
# 15              Soul music   9.578031    -0.024002   8.825146
# 16                   Blues   5.436104    -0.029352   5.185603
# 17        Psychedelic rock   3.460667    -0.019562   3.294603
# 18                     NaN        NaN          NaN        NaN
# 19          Schlager music   0.489164    -0.037371   0.570035
# 20                     NaN        NaN          NaN        NaN
# 21            Trance music   1.195870    -0.035828   1.142412
# 22               Indie pop   4.573590    -0.028500   4.608536
# 23                     NaN        NaN          NaN        NaN
# 24                     NaN        NaN          NaN        NaN
# 25                     NaN        NaN          NaN        NaN
# 26                     NaN        NaN          NaN        NaN
# 27                 Baroque   0.704329    -0.001033   0.904201
# 28  Electronic dance music   2.748397    -0.004157   2.536886
# 29                     NaN        NaN          NaN        NaN
# 30               Hard rock  10.420142    -0.017677   9.550473
# 31              Trap music   1.624345    -0.036765   1.376939
# 32                   Disco   2.759526    -0.035092   2.519100
# 33                     NaN        NaN          NaN        NaN
# 34         Musical theatre   0.539246    -0.007850   0.564469
# 35               Dance-pop   5.476912    -0.032206   5.107602
# 36           Rock and roll   3.785270    -0.031472   3.550688
# 37                   Opera   0.735862    -0.005143   0.879997

# %%
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 1
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 5
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 10
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 57
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 2
# P@1: 0.03508771929824561
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 115
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 5
# P@2: 0.043478260869565216
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 289
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 10
# P@5: 0.03460207612456748
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 579
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 11
# P@10: 0.018998272884283247
# =====================================
#                                              resource  amount  \
# 0              http://dbpedia.org/resource/Rock_music      56
# 1               http://dbpedia.org/resource/Pop_music      51
# 2           http://dbpedia.org/resource/Hip_hop_music      51
# 3                    http://dbpedia.org/resource/Jazz      27
# 4         http://dbpedia.org/resource/Classical_music      26
# 5       http://dbpedia.org/resource/Heavy_metal_music      20
# 6                  http://dbpedia.org/resource/Techno      20
# 7             http://dbpedia.org/resource/House_music       8
# 8        http://dbpedia.org/resource/Rhythm_and_blues       7
# 9              http://dbpedia.org/resource/Indie_rock       6
# 10              http://dbpedia.org/resource/Punk_rock       6
# 11            http://dbpedia.org/resource/Swing_music       4
# 12        http://dbpedia.org/resource/Electro_(music)       3
# 13          http://dbpedia.org/resource/Country_music       3
# 14                   http://dbpedia.org/resource/Funk       3
# 15             http://dbpedia.org/resource/Soul_music       3
# 16                  http://dbpedia.org/resource/Blues       3
# 17       http://dbpedia.org/resource/Psychedelic_rock       3
# 18              http://dbpedia.org/resource/Hardstyle       2
# 19         http://dbpedia.org/resource/Schlager_music       2
# 20           http://dbpedia.org/resource/Echo_Klassik       2
# 21           http://dbpedia.org/resource/Trance_music       2
# 22              http://dbpedia.org/resource/Indie_pop       1
# 23           http://dbpedia.org/resource/Black_pepper       1
# 24       http://dbpedia.org/resource/Mushroom_Records       1
# 25                 http://dbpedia.org/resource/Carrot       1
# 26        http://dbpedia.org/resource/Romance_(music)       1
# 27                http://dbpedia.org/resource/Baroque       1
# 28  http://dbpedia.org/resource/Electronic_dance_m...       1
# 29             http://dbpedia.org/resource/Conducting       1
# 30              http://dbpedia.org/resource/Hard_rock       1
# 31             http://dbpedia.org/resource/Trap_music       1
# 32                  http://dbpedia.org/resource/Disco       1
# 33         http://dbpedia.org/resource/German_hip_hop       1
# 34        http://dbpedia.org/resource/Musical_theatre       1
# 35              http://dbpedia.org/resource/Dance-pop       1
# 36          http://dbpedia.org/resource/Rock_and_roll       1
# 37                  http://dbpedia.org/resource/Opera       1
#
#                       name     degree  eigenvector   pagerank
# 0               Rock music  19.965306     0.012149  19.579307
# 1                Pop music  32.201888     0.037286  31.603269
# 2            Hip hop music  18.453587    -0.004172  17.043364
# 3                     Jazz  15.016511     0.000039  14.861902
# 4          Classical music   4.898192     0.009477   5.268666
# 5                      NaN        NaN          NaN        NaN
# 6                      NaN        NaN          NaN        NaN
# 7              House music   4.280520     0.000865   4.058736
# 8                      NaN        NaN          NaN        NaN
# 9                      NaN        NaN          NaN        NaN
# 10                     NaN        NaN          NaN        NaN
# 11                     NaN        NaN          NaN        NaN
# 12         Electro (music)   1.119820    -0.007088   1.040245
# 13                     NaN        NaN          NaN        NaN
# 14                     NaN        NaN          NaN        NaN
# 15                     NaN        NaN          NaN        NaN
# 16                     NaN        NaN          NaN        NaN
# 17                     NaN        NaN          NaN        NaN
# 18                     NaN        NaN          NaN        NaN
# 19                     NaN        NaN          NaN        NaN
# 20                     NaN        NaN          NaN        NaN
# 21                     NaN        NaN          NaN        NaN
# 22                     NaN        NaN          NaN        NaN
# 23                     NaN        NaN          NaN        NaN
# 24                     NaN        NaN          NaN        NaN
# 25                     NaN        NaN          NaN        NaN
# 26                     NaN        NaN          NaN        NaN
# 27                 Baroque   0.704329    -0.001033   0.904201
# 28  Electronic dance music   2.748397    -0.004157   2.536886
# 29                     NaN        NaN          NaN        NaN
# 30                     NaN        NaN          NaN        NaN
# 31                     NaN        NaN          NaN        NaN
# 32                     NaN        NaN          NaN        NaN
# 33                     NaN        NaN          NaN        NaN
# 34         Musical theatre   0.539246    -0.007850   0.564469
# 35                     NaN        NaN          NaN        NaN
# 36                     NaN        NaN          NaN        NaN
# 37                   Opera   0.735862    -0.005143   0.879997

# %%
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_music_genres, musicGenres_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 1
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 5
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 10
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 6
# P@10: 0.6
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 57
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 19
# P@1: 0.3333333333333333
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 115
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 21
# P@2: 0.1826086956521739
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 289
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 30
# P@5: 0.10380622837370242
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 5790
# DBpedia entries taken: top 579
# Entries in the gold standard: 38
# -------------------------------------
# HITS: 30
# P@10: 0.05181347150259067
# =====================================
#                                              resource  amount  \
# 0              http://dbpedia.org/resource/Rock_music      56
# 1               http://dbpedia.org/resource/Pop_music      51
# 2           http://dbpedia.org/resource/Hip_hop_music      51
# 3                    http://dbpedia.org/resource/Jazz      27
# 4         http://dbpedia.org/resource/Classical_music      26
# 5       http://dbpedia.org/resource/Heavy_metal_music      20
# 6                  http://dbpedia.org/resource/Techno      20
# 7             http://dbpedia.org/resource/House_music       8
# 8        http://dbpedia.org/resource/Rhythm_and_blues       7
# 9              http://dbpedia.org/resource/Indie_rock       6
# 10              http://dbpedia.org/resource/Punk_rock       6
# 11            http://dbpedia.org/resource/Swing_music       4
# 12        http://dbpedia.org/resource/Electro_(music)       3
# 13          http://dbpedia.org/resource/Country_music       3
# 14                   http://dbpedia.org/resource/Funk       3
# 15             http://dbpedia.org/resource/Soul_music       3
# 16                  http://dbpedia.org/resource/Blues       3
# 17       http://dbpedia.org/resource/Psychedelic_rock       3
# 18              http://dbpedia.org/resource/Hardstyle       2
# 19         http://dbpedia.org/resource/Schlager_music       2
# 20           http://dbpedia.org/resource/Echo_Klassik       2
# 21           http://dbpedia.org/resource/Trance_music       2
# 22              http://dbpedia.org/resource/Indie_pop       1
# 23           http://dbpedia.org/resource/Black_pepper       1
# 24       http://dbpedia.org/resource/Mushroom_Records       1
# 25                 http://dbpedia.org/resource/Carrot       1
# 26        http://dbpedia.org/resource/Romance_(music)       1
# 27                http://dbpedia.org/resource/Baroque       1
# 28  http://dbpedia.org/resource/Electronic_dance_m...       1
# 29             http://dbpedia.org/resource/Conducting       1
# 30              http://dbpedia.org/resource/Hard_rock       1
# 31             http://dbpedia.org/resource/Trap_music       1
# 32                  http://dbpedia.org/resource/Disco       1
# 33         http://dbpedia.org/resource/German_hip_hop       1
# 34        http://dbpedia.org/resource/Musical_theatre       1
# 35              http://dbpedia.org/resource/Dance-pop       1
# 36          http://dbpedia.org/resource/Rock_and_roll       1
# 37                  http://dbpedia.org/resource/Opera       1
#
#                       name     degree  eigenvector   pagerank
# 0               Rock music  19.965306     0.012149  19.579307
# 1                Pop music  32.201888     0.037286  31.603269
# 2            Hip hop music  18.453587    -0.004172  17.043364
# 3                     Jazz  15.016511     0.000039  14.861902
# 4          Classical music   4.898192     0.009477   5.268666
# 5        Heavy metal music   7.240894    -0.022154   6.728153
# 6                   Techno   1.405470    -0.034476   1.337463
# 7              House music   4.280520     0.000865   4.058736
# 8         Rhythm and blues   9.587305    -0.023769   8.901624
# 9               Indie rock  12.334368    -0.009423  12.410688
# 10               Punk rock   8.463253    -0.017253   8.311717
# 11             Swing music   0.728443    -0.037940   0.644756
# 12         Electro (music)   1.119820    -0.007088   1.040245
# 13           Country music  23.133426    -0.029161  23.206595
# 14                    Funk   4.799884    -0.030529   4.370521
# 15              Soul music   9.578031    -0.024002   8.825146
# 16                   Blues   5.436104    -0.029352   5.185603
# 17        Psychedelic rock   3.460667    -0.019562   3.294603
# 18                     NaN        NaN          NaN        NaN
# 19          Schlager music   0.489164    -0.037371   0.570035
# 20                     NaN        NaN          NaN        NaN
# 21            Trance music   1.195870    -0.035828   1.142412
# 22               Indie pop   4.573590    -0.028500   4.608536
# 23                     NaN        NaN          NaN        NaN
# 24                     NaN        NaN          NaN        NaN
# 25                     NaN        NaN          NaN        NaN
# 26                     NaN        NaN          NaN        NaN
# 27                 Baroque   0.704329    -0.001033   0.904201
# 28  Electronic dance music   2.748397    -0.004157   2.536886
# 29                     NaN        NaN          NaN        NaN
# 30               Hard rock  10.420142    -0.017677   9.550473
# 31              Trap music   1.624345    -0.036765   1.376939
# 32                   Disco   2.759526    -0.035092   2.519100
# 33                     NaN        NaN          NaN        NaN
# 34         Musical theatre   0.539246    -0.007850   0.564469
# 35               Dance-pop   5.476912    -0.032206   5.107602
# 36           Rock and roll   3.785270    -0.031472   3.550688
# 37                   Opera   0.735862    -0.005143   0.879997

# %% [markdown]
# ### US presidents

# %%
precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=10, opt='n')

#precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=1, opt='p')
#precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 1
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 5
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 10
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 2
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 4
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 4
# P@10: 1.0
# =====================================
#                                              resource  amount            name  \
# 0            http://dbpedia.org/resource/Barack_Obama      77    Barack Obama
# 1            http://dbpedia.org/resource/Donald_Trump      59    Donald Trump
# 2               http://dbpedia.org/resource/Joe_Biden      50       Joe Biden
# 3          http://dbpedia.org/resource/George_W._Bush      37  George W. Bush
# 4         http://dbpedia.org/resource/Abraham_Lincoln      19             NaN
# 5         http://dbpedia.org/resource/John_F._Kennedy      17             NaN
# 6            http://dbpedia.org/resource/Bill_Clinton      15             NaN
# 7       http://dbpedia.org/resource/George_Washington      14             NaN
# 8   http://dbpedia.org/resource/Franklin_D._Roosevelt      10             NaN
# 9           http://dbpedia.org/resource/Ronald_Reagan       5             NaN
# 10          http://dbpedia.org/resource/Richard_Nixon       4             NaN
# 11       http://dbpedia.org/resource/Thomas_Jefferson       3             NaN
# 12           http://dbpedia.org/resource/Jimmy_Carter       2             NaN
# 13            http://dbpedia.org/resource/Gerald_Ford       2             NaN
# 14      http://dbpedia.org/resource/George_H._W._Bush       2             NaN
# 15   http://dbpedia.org/resource/Dwight_D._Eisenhower       1             NaN
# 16      http://dbpedia.org/resource/John_Quincy_Adams       1             NaN
# 17          http://dbpedia.org/resource/James_Madison       1             NaN
# 18         http://dbpedia.org/resource/Woodrow_Wilson       1             NaN
#
#       degree  eigenvector  pagerank
# 0   3.708055    -0.352442  3.687696
# 1   3.295256    -0.525472  3.347980
# 2   1.604187    -0.478987  1.641248
# 3   2.558785     0.603578  2.562086
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN

# %%
precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=10, opt='n')

#precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=1, opt='p')
#precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 1
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 5
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 2
# P@5: 0.4
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 10
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 6
# P@10: 0.6
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 2
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 1
# P@5: 0.5
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 4
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 2
# P@10: 0.5
# =====================================
#                                              resource  amount  \
# 0            http://dbpedia.org/resource/Barack_Obama      77
# 1            http://dbpedia.org/resource/Donald_Trump      59
# 2               http://dbpedia.org/resource/Joe_Biden      50
# 3          http://dbpedia.org/resource/George_W._Bush      37
# 4         http://dbpedia.org/resource/Abraham_Lincoln      19
# 5         http://dbpedia.org/resource/John_F._Kennedy      17
# 6            http://dbpedia.org/resource/Bill_Clinton      15
# 7       http://dbpedia.org/resource/George_Washington      14
# 8   http://dbpedia.org/resource/Franklin_D._Roosevelt      10
# 9           http://dbpedia.org/resource/Ronald_Reagan       5
# 10          http://dbpedia.org/resource/Richard_Nixon       4
# 11       http://dbpedia.org/resource/Thomas_Jefferson       3
# 12           http://dbpedia.org/resource/Jimmy_Carter       2
# 13            http://dbpedia.org/resource/Gerald_Ford       2
# 14      http://dbpedia.org/resource/George_H._W._Bush       2
# 15   http://dbpedia.org/resource/Dwight_D._Eisenhower       1
# 16      http://dbpedia.org/resource/John_Quincy_Adams       1
# 17          http://dbpedia.org/resource/James_Madison       1
# 18         http://dbpedia.org/resource/Woodrow_Wilson       1
#
#                      name    degree  eigenvector  pagerank
# 0                     NaN       NaN          NaN       NaN
# 1                     NaN       NaN          NaN       NaN
# 2                     NaN       NaN          NaN       NaN
# 3                     NaN       NaN          NaN       NaN
# 4                     NaN       NaN          NaN       NaN
# 5                     NaN       NaN          NaN       NaN
# 6                     NaN       NaN          NaN       NaN
# 7                     NaN       NaN          NaN       NaN
# 8   Franklin D. Roosevelt  0.328263     1.156010  0.330174
# 9                     NaN       NaN          NaN       NaN
# 10                    NaN       NaN          NaN       NaN
# 11                    NaN       NaN          NaN       NaN
# 12                    NaN       NaN          NaN       NaN
# 13            Gerald Ford  0.074955     5.750697  0.037606
# 14                    NaN       NaN          NaN       NaN
# 15                    NaN       NaN          NaN       NaN
# 16                    NaN       NaN          NaN       NaN
# 17                    NaN       NaN          NaN       NaN
# 18                    NaN       NaN          NaN       NaN

# %%
precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=10, opt='n')

#precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=1, opt='p')
#precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_potus, potus_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 1
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 5
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 10
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 2
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 47
# DBpedia entries taken: top 4
# Entries in the gold standard: 19
# -------------------------------------
# HITS: 4
# P@10: 1.0
# =====================================
#                                              resource  amount            name  \
# 0            http://dbpedia.org/resource/Barack_Obama      77    Barack Obama
# 1            http://dbpedia.org/resource/Donald_Trump      59    Donald Trump
# 2               http://dbpedia.org/resource/Joe_Biden      50       Joe Biden
# 3          http://dbpedia.org/resource/George_W._Bush      37  George W. Bush
# 4         http://dbpedia.org/resource/Abraham_Lincoln      19             NaN
# 5         http://dbpedia.org/resource/John_F._Kennedy      17             NaN
# 6            http://dbpedia.org/resource/Bill_Clinton      15             NaN
# 7       http://dbpedia.org/resource/George_Washington      14             NaN
# 8   http://dbpedia.org/resource/Franklin_D._Roosevelt      10             NaN
# 9           http://dbpedia.org/resource/Ronald_Reagan       5             NaN
# 10          http://dbpedia.org/resource/Richard_Nixon       4             NaN
# 11       http://dbpedia.org/resource/Thomas_Jefferson       3             NaN
# 12           http://dbpedia.org/resource/Jimmy_Carter       2             NaN
# 13            http://dbpedia.org/resource/Gerald_Ford       2             NaN
# 14      http://dbpedia.org/resource/George_H._W._Bush       2             NaN
# 15   http://dbpedia.org/resource/Dwight_D._Eisenhower       1             NaN
# 16      http://dbpedia.org/resource/John_Quincy_Adams       1             NaN
# 17          http://dbpedia.org/resource/James_Madison       1             NaN
# 18         http://dbpedia.org/resource/Woodrow_Wilson       1             NaN
#
#       degree  eigenvector  pagerank
# 0   3.708055    -0.352442  3.687696
# 1   3.295256    -0.525472  3.347980
# 2   1.604187    -0.478987  1.641248
# 3   2.558785     0.603578  2.562086
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN

# %% [markdown]
# ### Lakes

# %%
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 1
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 5
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 10
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 1
# P@10: 0.1
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 93
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 16
# P@1: 0.17204301075268819
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 186
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 24
# P@2: 0.12903225806451613
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 466
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 26
# P@5: 0.055793991416309016
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 933
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 30
# P@10: 0.03215434083601286
# =====================================
#                                       resource  amount            name  \
# 0   http://dbpedia.org/resource/Lake_Constance      70  Lake Constance
# 1       http://dbpedia.org/resource/Lake_Garda      22      Lake Garda
# 2         http://dbpedia.org/resource/Michigan      15             NaN
# 3         http://dbpedia.org/resource/Chiemsee      15        Chiemsee
# 4    http://dbpedia.org/resource/Lake_Victoria      13   Lake Victoria
# ..                                         ...     ...             ...
# 65           http://dbpedia.org/resource/Rhine       1             NaN
# 66      http://dbpedia.org/resource/Walchensee       1      Walchensee
# 67    http://dbpedia.org/resource/Sacrower_See       1             NaN
# 68     http://dbpedia.org/resource/Liepnitzsee       1             NaN
# 69      http://dbpedia.org/resource/Schliersee       1             NaN
#
#       degree  eigenvector  pagerank
# 0   2.522217    -0.738777  2.966051
# 1   1.088362     4.174926  1.201136
# 2        NaN          NaN       NaN
# 3   0.426582     0.488262  0.643024
# 4   4.176666    -0.282357  3.991495
# ..       ...          ...       ...
# 65       NaN          NaN       NaN
# 66  0.205989     0.484088  0.346317
# 67       NaN          NaN       NaN
# 68       NaN          NaN       NaN
# 69       NaN          NaN       NaN
#
# [70 rows x 6 columns]

# %%
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 1
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 5
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 10
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 93
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 3
# P@1: 0.03225806451612903
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 186
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 4
# P@2: 0.021505376344086023
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 466
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 5
# P@5: 0.01072961373390558
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 933
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 11
# P@10: 0.011789924973204717
# =====================================
#                                       resource  amount        name    degree  \
# 0   http://dbpedia.org/resource/Lake_Constance      70         NaN       NaN
# 1       http://dbpedia.org/resource/Lake_Garda      22  Lake Garda  1.088362
# 2         http://dbpedia.org/resource/Michigan      15         NaN       NaN
# 3         http://dbpedia.org/resource/Chiemsee      15         NaN       NaN
# 4    http://dbpedia.org/resource/Lake_Victoria      13         NaN       NaN
# ..                                         ...     ...         ...       ...
# 65           http://dbpedia.org/resource/Rhine       1         NaN       NaN
# 66      http://dbpedia.org/resource/Walchensee       1         NaN       NaN
# 67    http://dbpedia.org/resource/Sacrower_See       1         NaN       NaN
# 68     http://dbpedia.org/resource/Liepnitzsee       1         NaN       NaN
# 69      http://dbpedia.org/resource/Schliersee       1         NaN       NaN
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      4.174926  1.201136
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ..          ...       ...
# 65          NaN       NaN
# 66          NaN       NaN
# 67          NaN       NaN
# 68          NaN       NaN
# 69          NaN       NaN
#
# [70 rows x 6 columns]

# %%
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_lakes, lakes_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 1
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 5
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 10
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 1
# P@10: 0.1
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 93
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 15
# P@1: 0.16129032258064516
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 186
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 20
# P@2: 0.10752688172043011
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 466
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 27
# P@5: 0.05793991416309013
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9335
# DBpedia entries taken: top 933
# Entries in the gold standard: 70
# -------------------------------------
# HITS: 31
# P@10: 0.03322615219721329
# =====================================
#                                       resource  amount            name  \
# 0   http://dbpedia.org/resource/Lake_Constance      70  Lake Constance
# 1       http://dbpedia.org/resource/Lake_Garda      22      Lake Garda
# 2         http://dbpedia.org/resource/Michigan      15             NaN
# 3         http://dbpedia.org/resource/Chiemsee      15        Chiemsee
# 4    http://dbpedia.org/resource/Lake_Victoria      13   Lake Victoria
# ..                                         ...     ...             ...
# 65           http://dbpedia.org/resource/Rhine       1             NaN
# 66      http://dbpedia.org/resource/Walchensee       1      Walchensee
# 67    http://dbpedia.org/resource/Sacrower_See       1             NaN
# 68     http://dbpedia.org/resource/Liepnitzsee       1             NaN
# 69      http://dbpedia.org/resource/Schliersee       1             NaN
#
#       degree  eigenvector  pagerank
# 0   2.522217    -0.738777  2.966051
# 1   1.088362     4.174926  1.201136
# 2        NaN          NaN       NaN
# 3   0.426582     0.488262  0.643024
# 4   4.176666    -0.282357  3.991495
# ..       ...          ...       ...
# 65       NaN          NaN       NaN
# 66  0.205989     0.484088  0.346317
# 67       NaN          NaN       NaN
# 68       NaN          NaN       NaN
# 69       NaN          NaN       NaN
#
# [70 rows x 6 columns]

# %% [markdown]
# ### Mountains

# %%
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 1
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 5
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 1
# P@5: 0.2
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 10
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 2
# P@10: 0.2
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 90
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 7
# P@1: 0.07777777777777778
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 181
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 12
# P@2: 0.06629834254143646
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 453
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 16
# P@5: 0.03532008830022075
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 906
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 21
# P@10: 0.023178807947019868
# =====================================
#                                              resource  amount  \
# 0           http://dbpedia.org/resource/Mount_Everest      68
# 1               http://dbpedia.org/resource/Zugspitze      65
# 2                      http://dbpedia.org/resource/K2      29
# 3       http://dbpedia.org/resource/Mount_Kilimanjaro      21
# 4                http://dbpedia.org/resource/Chamonix      21
# 5   http://dbpedia.org/resource/Matterhorn_Gotthar...      19
# 6   http://dbpedia.org/resource/Feldberg_(Black_Fo...       9
# 7            http://dbpedia.org/resource/Pennine_Alps       7
# 8         http://dbpedia.org/resource/Brocken_spectre       5
# 9            http://dbpedia.org/resource/Nanga_Parbat       4
# 10              http://dbpedia.org/resource/Himalayas       4
# 11             http://dbpedia.org/resource/Mont_Blanc       3
# 12             http://dbpedia.org/resource/Königstuhl       3
# 13  http://dbpedia.org/resource/Grossglockner_High...       3
# 14             http://dbpedia.org/resource/Mount_Fuji       3
# 15               http://dbpedia.org/resource/Watzmann       2
# 16               http://dbpedia.org/resource/Pyrenees       2
# 17                  http://dbpedia.org/resource/Uluru       2
# 18                  http://dbpedia.org/resource/Eiger       2
# 19              http://dbpedia.org/resource/Dolomites       2
# 20       http://dbpedia.org/resource/Canadian_Rockies       2
# 21   http://dbpedia.org/resource/Carpathian_Mountains       2
# 22             http://dbpedia.org/resource/Mount_Etna       1
# 23              http://dbpedia.org/resource/Aconcagua       1
# 24    http://dbpedia.org/resource/Vosges_(department)       1
# 25       http://dbpedia.org/resource/NK_Triglav_Kranj       1
# 26  http://dbpedia.org/resource/Yokohama_DeNA_BayS...       1
# 27  http://dbpedia.org/resource/Central_District_(...       1
# 28            http://dbpedia.org/resource/Val-d'Isère       1
# 29                http://dbpedia.org/resource/Stetind       1
# 30              http://dbpedia.org/resource/Kreuzberg       1
# 31         http://dbpedia.org/resource/Ural_Mountains       1
# 32           http://dbpedia.org/resource/Katzenbuckel       1
# 33         http://dbpedia.org/resource/Józef_Tischner       1
# 34              http://dbpedia.org/resource/Ben_Nevis       1
# 35          http://dbpedia.org/resource/Rouyn-Noranda       1
# 36            http://dbpedia.org/resource/Puy-de-Dôme       1
# 37    http://dbpedia.org/resource/Chimborazo_Province       1
# 38   http://dbpedia.org/resource/Montblanc,_Tarragona       1
# 39              http://dbpedia.org/resource/Weissfluh       1
# 40      http://dbpedia.org/resource/Jura_(department)       1
# 41           http://dbpedia.org/resource/South_Dakota       1
# 42  http://dbpedia.org/resource/Weißer_Stein_(Voge...       1
# 43             http://dbpedia.org/resource/Max_Martin       1
# 44    http://dbpedia.org/resource/Praise-God_Barebone       1
# 45              http://dbpedia.org/resource/Karwendel       1
# 46               http://dbpedia.org/resource/Piz_Buin       1
# 47  http://dbpedia.org/resource/Appalachian_Mountains       1
# 48             http://dbpedia.org/resource/Kebnekaise       1
# 49             http://dbpedia.org/resource/Hungerburg       1
# 50         http://dbpedia.org/resource/Single_(music)       1
# 51          http://dbpedia.org/resource/Mount_Olympus       1
# 52          http://dbpedia.org/resource/Mount_Wilhelm       1
# 53           http://dbpedia.org/resource/Machu_Picchu       1
# 54           http://dbpedia.org/resource/Mount_Elbrus       1
# 55  http://dbpedia.org/resource/Ferrara_di_Monte_B...       1
#
#                      name     degree  eigenvector   pagerank
# 0           Mount Everest   1.969125    -0.150577   2.157380
# 1               Zugspitze   0.162833     0.656033   0.178419
# 2                      K2   0.377139    -0.432434   0.448797
# 3       Mount Kilimanjaro   0.744520    -0.417605   0.906696
# 4                     NaN        NaN          NaN        NaN
# 5                     NaN        NaN          NaN        NaN
# 6                     NaN        NaN          NaN        NaN
# 7                     NaN        NaN          NaN        NaN
# 8                     NaN        NaN          NaN        NaN
# 9            Nanga Parbat   0.193448    -0.433027   0.256582
# 10              Himalayas   6.347089     0.153414   6.667515
# 11             Mont Blanc   0.499599     2.870304   0.607238
# 12                    NaN        NaN          NaN        NaN
# 13                    NaN        NaN          NaN        NaN
# 14             Mount Fuji   0.070987     0.860393   0.137418
# 15                    NaN        NaN          NaN        NaN
# 16               Pyrenees   5.214329    -0.304074   5.562095
# 17                    NaN        NaN          NaN        NaN
# 18                  Eiger   0.040372    -0.131171   0.093157
# 19              Dolomites   1.907895     2.012069   2.122581
# 20       Canadian Rockies  10.051520    -0.360762  10.514287
# 21   Carpathian Mountains   0.622060    -0.427939   0.736941
# 22             Mount Etna   0.040372     1.917463   0.068212
# 23              Aconcagua   0.101602     0.986042   0.105455
# 24                    NaN        NaN          NaN        NaN
# 25                    NaN        NaN          NaN        NaN
# 26                    NaN        NaN          NaN        NaN
# 27                    NaN        NaN          NaN        NaN
# 28                    NaN        NaN          NaN        NaN
# 29                    NaN        NaN          NaN        NaN
# 30                    NaN        NaN          NaN        NaN
# 31         Ural Mountains   0.377139    -0.429819   0.453670
# 32                    NaN        NaN          NaN        NaN
# 33                    NaN        NaN          NaN        NaN
# 34                    NaN        NaN          NaN        NaN
# 35                    NaN        NaN          NaN        NaN
# 36                    NaN        NaN          NaN        NaN
# 37                    NaN        NaN          NaN        NaN
# 38                    NaN        NaN          NaN        NaN
# 39                    NaN        NaN          NaN        NaN
# 40                    NaN        NaN          NaN        NaN
# 41                    NaN        NaN          NaN        NaN
# 42                    NaN        NaN          NaN        NaN
# 43                    NaN        NaN          NaN        NaN
# 44                    NaN        NaN          NaN        NaN
# 45              Karwendel   1.081287    -0.425014   1.110285
# 46               Piz Buin   0.040372     0.365632   0.036215
# 47  Appalachian Mountains   3.438652    -0.409255   3.436348
# 48                    NaN        NaN          NaN        NaN
# 49                    NaN        NaN          NaN        NaN
# 50                    NaN        NaN          NaN        NaN
# 51          Mount Olympus   0.132218     0.024431   0.179005
# 52          Mount Wilhelm   0.070987    -0.415525   0.059991
# 53                    NaN        NaN          NaN        NaN
# 54                    NaN        NaN          NaN        NaN
# 55                    NaN        NaN          NaN        NaN

# %%
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 1
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 5
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 10
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 1
# P@10: 0.1
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 90
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 1
# P@1: 0.011111111111111112
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 181
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 2
# P@2: 0.011049723756906077
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 453
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 3
# P@5: 0.006622516556291391
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 906
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 7
# P@10: 0.00772626931567329
# =====================================
#                                              resource  amount          name  \
# 0           http://dbpedia.org/resource/Mount_Everest      68           NaN
# 1               http://dbpedia.org/resource/Zugspitze      65     Zugspitze
# 2                      http://dbpedia.org/resource/K2      29           NaN
# 3       http://dbpedia.org/resource/Mount_Kilimanjaro      21           NaN
# 4                http://dbpedia.org/resource/Chamonix      21           NaN
# 5   http://dbpedia.org/resource/Matterhorn_Gotthar...      19           NaN
# 6   http://dbpedia.org/resource/Feldberg_(Black_Fo...       9           NaN
# 7            http://dbpedia.org/resource/Pennine_Alps       7           NaN
# 8         http://dbpedia.org/resource/Brocken_spectre       5           NaN
# 9            http://dbpedia.org/resource/Nanga_Parbat       4           NaN
# 10              http://dbpedia.org/resource/Himalayas       4           NaN
# 11             http://dbpedia.org/resource/Mont_Blanc       3    Mont Blanc
# 12             http://dbpedia.org/resource/Königstuhl       3           NaN
# 13  http://dbpedia.org/resource/Grossglockner_High...       3           NaN
# 14             http://dbpedia.org/resource/Mount_Fuji       3    Mount Fuji
# 15               http://dbpedia.org/resource/Watzmann       2           NaN
# 16               http://dbpedia.org/resource/Pyrenees       2           NaN
# 17                  http://dbpedia.org/resource/Uluru       2           NaN
# 18                  http://dbpedia.org/resource/Eiger       2           NaN
# 19              http://dbpedia.org/resource/Dolomites       2     Dolomites
# 20       http://dbpedia.org/resource/Canadian_Rockies       2           NaN
# 21   http://dbpedia.org/resource/Carpathian_Mountains       2           NaN
# 22             http://dbpedia.org/resource/Mount_Etna       1    Mount Etna
# 23              http://dbpedia.org/resource/Aconcagua       1     Aconcagua
# 24    http://dbpedia.org/resource/Vosges_(department)       1           NaN
# 25       http://dbpedia.org/resource/NK_Triglav_Kranj       1           NaN
# 26  http://dbpedia.org/resource/Yokohama_DeNA_BayS...       1           NaN
# 27  http://dbpedia.org/resource/Central_District_(...       1           NaN
# 28            http://dbpedia.org/resource/Val-d'Isère       1           NaN
# 29                http://dbpedia.org/resource/Stetind       1           NaN
# 30              http://dbpedia.org/resource/Kreuzberg       1           NaN
# 31         http://dbpedia.org/resource/Ural_Mountains       1           NaN
# 32           http://dbpedia.org/resource/Katzenbuckel       1           NaN
# 33         http://dbpedia.org/resource/Józef_Tischner       1           NaN
# 34              http://dbpedia.org/resource/Ben_Nevis       1           NaN
# 35          http://dbpedia.org/resource/Rouyn-Noranda       1           NaN
# 36            http://dbpedia.org/resource/Puy-de-Dôme       1           NaN
# 37    http://dbpedia.org/resource/Chimborazo_Province       1           NaN
# 38   http://dbpedia.org/resource/Montblanc,_Tarragona       1           NaN
# 39              http://dbpedia.org/resource/Weissfluh       1           NaN
# 40      http://dbpedia.org/resource/Jura_(department)       1           NaN
# 41           http://dbpedia.org/resource/South_Dakota       1           NaN
# 42  http://dbpedia.org/resource/Weißer_Stein_(Voge...       1           NaN
# 43             http://dbpedia.org/resource/Max_Martin       1           NaN
# 44    http://dbpedia.org/resource/Praise-God_Barebone       1           NaN
# 45              http://dbpedia.org/resource/Karwendel       1           NaN
# 46               http://dbpedia.org/resource/Piz_Buin       1           NaN
# 47  http://dbpedia.org/resource/Appalachian_Mountains       1           NaN
# 48             http://dbpedia.org/resource/Kebnekaise       1           NaN
# 49             http://dbpedia.org/resource/Hungerburg       1           NaN
# 50         http://dbpedia.org/resource/Single_(music)       1           NaN
# 51          http://dbpedia.org/resource/Mount_Olympus       1           NaN
# 52          http://dbpedia.org/resource/Mount_Wilhelm       1           NaN
# 53           http://dbpedia.org/resource/Machu_Picchu       1           NaN
# 54           http://dbpedia.org/resource/Mount_Elbrus       1  Mount Elbrus
# 55  http://dbpedia.org/resource/Ferrara_di_Monte_B...       1           NaN
#
#       degree  eigenvector  pagerank
# 0        NaN          NaN       NaN
# 1   0.162833     0.656033  0.178419
# 2        NaN          NaN       NaN
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11  0.499599     2.870304  0.607238
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14  0.070987     0.860393  0.137418
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19  1.907895     2.012069  2.122581
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22  0.040372     1.917463  0.068212
# 23  0.101602     0.986042  0.105455
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28       NaN          NaN       NaN
# 29       NaN          NaN       NaN
# 30       NaN          NaN       NaN
# 31       NaN          NaN       NaN
# 32       NaN          NaN       NaN
# 33       NaN          NaN       NaN
# 34       NaN          NaN       NaN
# 35       NaN          NaN       NaN
# 36       NaN          NaN       NaN
# 37       NaN          NaN       NaN
# 38       NaN          NaN       NaN
# 39       NaN          NaN       NaN
# 40       NaN          NaN       NaN
# 41       NaN          NaN       NaN
# 42       NaN          NaN       NaN
# 43       NaN          NaN       NaN
# 44       NaN          NaN       NaN
# 45       NaN          NaN       NaN
# 46       NaN          NaN       NaN
# 47       NaN          NaN       NaN
# 48       NaN          NaN       NaN
# 49       NaN          NaN       NaN
# 50       NaN          NaN       NaN
# 51       NaN          NaN       NaN
# 52       NaN          NaN       NaN
# 53       NaN          NaN       NaN
# 54  0.009757     0.889768  0.052973
# 55       NaN          NaN       NaN

# %%
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_mountains, mountains_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 1
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 5
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 1
# P@5: 0.2
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 10
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 3
# P@10: 0.3
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 90
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 8
# P@1: 0.08888888888888889
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 181
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 12
# P@2: 0.06629834254143646
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 453
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 17
# P@5: 0.037527593818984545
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 9065
# DBpedia entries taken: top 906
# Entries in the gold standard: 56
# -------------------------------------
# HITS: 23
# P@10: 0.025386313465783666
# =====================================
#                                              resource  amount  \
# 0           http://dbpedia.org/resource/Mount_Everest      68
# 1               http://dbpedia.org/resource/Zugspitze      65
# 2                      http://dbpedia.org/resource/K2      29
# 3       http://dbpedia.org/resource/Mount_Kilimanjaro      21
# 4                http://dbpedia.org/resource/Chamonix      21
# 5   http://dbpedia.org/resource/Matterhorn_Gotthar...      19
# 6   http://dbpedia.org/resource/Feldberg_(Black_Fo...       9
# 7            http://dbpedia.org/resource/Pennine_Alps       7
# 8         http://dbpedia.org/resource/Brocken_spectre       5
# 9            http://dbpedia.org/resource/Nanga_Parbat       4
# 10              http://dbpedia.org/resource/Himalayas       4
# 11             http://dbpedia.org/resource/Mont_Blanc       3
# 12             http://dbpedia.org/resource/Königstuhl       3
# 13  http://dbpedia.org/resource/Grossglockner_High...       3
# 14             http://dbpedia.org/resource/Mount_Fuji       3
# 15               http://dbpedia.org/resource/Watzmann       2
# 16               http://dbpedia.org/resource/Pyrenees       2
# 17                  http://dbpedia.org/resource/Uluru       2
# 18                  http://dbpedia.org/resource/Eiger       2
# 19              http://dbpedia.org/resource/Dolomites       2
# 20       http://dbpedia.org/resource/Canadian_Rockies       2
# 21   http://dbpedia.org/resource/Carpathian_Mountains       2
# 22             http://dbpedia.org/resource/Mount_Etna       1
# 23              http://dbpedia.org/resource/Aconcagua       1
# 24    http://dbpedia.org/resource/Vosges_(department)       1
# 25       http://dbpedia.org/resource/NK_Triglav_Kranj       1
# 26  http://dbpedia.org/resource/Yokohama_DeNA_BayS...       1
# 27  http://dbpedia.org/resource/Central_District_(...       1
# 28            http://dbpedia.org/resource/Val-d'Isère       1
# 29                http://dbpedia.org/resource/Stetind       1
# 30              http://dbpedia.org/resource/Kreuzberg       1
# 31         http://dbpedia.org/resource/Ural_Mountains       1
# 32           http://dbpedia.org/resource/Katzenbuckel       1
# 33         http://dbpedia.org/resource/Józef_Tischner       1
# 34              http://dbpedia.org/resource/Ben_Nevis       1
# 35          http://dbpedia.org/resource/Rouyn-Noranda       1
# 36            http://dbpedia.org/resource/Puy-de-Dôme       1
# 37    http://dbpedia.org/resource/Chimborazo_Province       1
# 38   http://dbpedia.org/resource/Montblanc,_Tarragona       1
# 39              http://dbpedia.org/resource/Weissfluh       1
# 40      http://dbpedia.org/resource/Jura_(department)       1
# 41           http://dbpedia.org/resource/South_Dakota       1
# 42  http://dbpedia.org/resource/Weißer_Stein_(Voge...       1
# 43             http://dbpedia.org/resource/Max_Martin       1
# 44    http://dbpedia.org/resource/Praise-God_Barebone       1
# 45              http://dbpedia.org/resource/Karwendel       1
# 46               http://dbpedia.org/resource/Piz_Buin       1
# 47  http://dbpedia.org/resource/Appalachian_Mountains       1
# 48             http://dbpedia.org/resource/Kebnekaise       1
# 49             http://dbpedia.org/resource/Hungerburg       1
# 50         http://dbpedia.org/resource/Single_(music)       1
# 51          http://dbpedia.org/resource/Mount_Olympus       1
# 52          http://dbpedia.org/resource/Mount_Wilhelm       1
# 53           http://dbpedia.org/resource/Machu_Picchu       1
# 54           http://dbpedia.org/resource/Mount_Elbrus       1
# 55  http://dbpedia.org/resource/Ferrara_di_Monte_B...       1
#
#                        name     degree  eigenvector   pagerank
# 0             Mount Everest   1.969125    -0.150577   2.157380
# 1                 Zugspitze   0.162833     0.656033   0.178419
# 2                        K2   0.377139    -0.432434   0.448797
# 3         Mount Kilimanjaro   0.744520    -0.417605   0.906696
# 4                       NaN        NaN          NaN        NaN
# 5                       NaN        NaN          NaN        NaN
# 6   Feldberg (Black Forest)   0.009757    -0.396636   0.043429
# 7                       NaN        NaN          NaN        NaN
# 8                       NaN        NaN          NaN        NaN
# 9              Nanga Parbat   0.193448    -0.433027   0.256582
# 10                Himalayas   6.347089     0.153414   6.667515
# 11               Mont Blanc   0.499599     2.870304   0.607238
# 12                      NaN        NaN          NaN        NaN
# 13                      NaN        NaN          NaN        NaN
# 14               Mount Fuji   0.070987     0.860393   0.137418
# 15                      NaN        NaN          NaN        NaN
# 16                 Pyrenees   5.214329    -0.304074   5.562095
# 17                      NaN        NaN          NaN        NaN
# 18                    Eiger   0.040372    -0.131171   0.093157
# 19                Dolomites   1.907895     2.012069   2.122581
# 20         Canadian Rockies  10.051520    -0.360762  10.514287
# 21     Carpathian Mountains   0.622060    -0.427939   0.736941
# 22               Mount Etna   0.040372     1.917463   0.068212
# 23                Aconcagua   0.101602     0.986042   0.105455
# 24                      NaN        NaN          NaN        NaN
# 25                      NaN        NaN          NaN        NaN
# 26                      NaN        NaN          NaN        NaN
# 27                      NaN        NaN          NaN        NaN
# 28                      NaN        NaN          NaN        NaN
# 29                      NaN        NaN          NaN        NaN
# 30                      NaN        NaN          NaN        NaN
# 31           Ural Mountains   0.377139    -0.429819   0.453670
# 32                      NaN        NaN          NaN        NaN
# 33                      NaN        NaN          NaN        NaN
# 34                      NaN        NaN          NaN        NaN
# 35                      NaN        NaN          NaN        NaN
# 36                      NaN        NaN          NaN        NaN
# 37                      NaN        NaN          NaN        NaN
# 38                      NaN        NaN          NaN        NaN
# 39                      NaN        NaN          NaN        NaN
# 40                      NaN        NaN          NaN        NaN
# 41                      NaN        NaN          NaN        NaN
# 42                      NaN        NaN          NaN        NaN
# 43                      NaN        NaN          NaN        NaN
# 44                      NaN        NaN          NaN        NaN
# 45                Karwendel   1.081287    -0.425014   1.110285
# 46                 Piz Buin   0.040372     0.365632   0.036215
# 47    Appalachian Mountains   3.438652    -0.409255   3.436348
# 48                      NaN        NaN          NaN        NaN
# 49                      NaN        NaN          NaN        NaN
# 50                      NaN        NaN          NaN        NaN
# 51            Mount Olympus   0.132218     0.024431   0.179005
# 52            Mount Wilhelm   0.070987    -0.415525   0.059991
# 53                      NaN        NaN          NaN        NaN
# 54             Mount Elbrus   0.009757     0.889768   0.052973
# 55                      NaN        NaN          NaN        NaN

# %% [markdown]
# ### European capital cities

# %%
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=10, opt='n')

#precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 10
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 2
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 5
# P@10: 1.0
# =====================================
#                                         resource  amount    name    degree  \
# 0             http://dbpedia.org/resource/Berlin      84     NaN       NaN
# 1              http://dbpedia.org/resource/Paris      74   Paris  2.174713
# 2             http://dbpedia.org/resource/London      45  London  5.766493
# 3               http://dbpedia.org/resource/Rome      29    Rome  1.090678
# 4             http://dbpedia.org/resource/Madrid      19     NaN       NaN
# 5             http://dbpedia.org/resource/Vienna       9     NaN       NaN
# 6   http://dbpedia.org/resource/City_of_Brussels       8     NaN       NaN
# 7             http://dbpedia.org/resource/Warsaw       7     NaN       NaN
# 8         http://dbpedia.org/resource/Copenhagen       7     NaN       NaN
# 9           http://dbpedia.org/resource/Helsinki       5     NaN       NaN
# 10         http://dbpedia.org/resource/Amsterdam       5     NaN       NaN
# 11            http://dbpedia.org/resource/Lisbon       4     NaN       NaN
# 12              http://dbpedia.org/resource/Kyiv       4     NaN       NaN
# 13         http://dbpedia.org/resource/Reykjavík       3     NaN       NaN
# 14            http://dbpedia.org/resource/Dublin       3  Dublin  0.786804
# 15         http://dbpedia.org/resource/Stockholm       3     NaN       NaN
# 16            http://dbpedia.org/resource/Moscow       2  Moscow  1.410590
# 17              http://dbpedia.org/resource/Oslo       2     NaN       NaN
# 18             http://dbpedia.org/resource/Sofia       2     NaN       NaN
# 19          http://dbpedia.org/resource/Valletta       2     NaN       NaN
# 20            http://dbpedia.org/resource/Athens       1     NaN       NaN
# 21         http://dbpedia.org/resource/Barcelona       1     NaN       NaN
# 22            http://dbpedia.org/resource/Prague       1     NaN       NaN
# 23          http://dbpedia.org/resource/Budapest       1     NaN       NaN
# 24             http://dbpedia.org/resource/Minsk       1     NaN       NaN
# 25             http://dbpedia.org/resource/Milan       1     NaN       NaN
# 26          http://dbpedia.org/resource/Tórshavn       1     NaN       NaN
# 27           http://dbpedia.org/resource/Belfast       1     NaN       NaN
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      0.671928  2.264122
# 2      2.675248  5.688451
# 3      0.751011  1.083243
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14     1.629269  0.799474
# 15          NaN       NaN
# 16     2.198230  1.356614
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN

# %%
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=10, opt='n')

#precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 10
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 9
# P@10: 0.9
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 0
# P@2: 0.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 2
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 1
# P@5: 0.5
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 4
# P@10: 0.8
# =====================================
#                                         resource  amount      name    degree  \
# 0             http://dbpedia.org/resource/Berlin      84       NaN       NaN
# 1              http://dbpedia.org/resource/Paris      74       NaN       NaN
# 2             http://dbpedia.org/resource/London      45    London  5.766493
# 3               http://dbpedia.org/resource/Rome      29       NaN       NaN
# 4             http://dbpedia.org/resource/Madrid      19       NaN       NaN
# 5             http://dbpedia.org/resource/Vienna       9       NaN       NaN
# 6   http://dbpedia.org/resource/City_of_Brussels       8       NaN       NaN
# 7             http://dbpedia.org/resource/Warsaw       7       NaN       NaN
# 8         http://dbpedia.org/resource/Copenhagen       7       NaN       NaN
# 9           http://dbpedia.org/resource/Helsinki       5       NaN       NaN
# 10         http://dbpedia.org/resource/Amsterdam       5       NaN       NaN
# 11            http://dbpedia.org/resource/Lisbon       4       NaN       NaN
# 12              http://dbpedia.org/resource/Kyiv       4       NaN       NaN
# 13         http://dbpedia.org/resource/Reykjavík       3       NaN       NaN
# 14            http://dbpedia.org/resource/Dublin       3    Dublin  0.786804
# 15         http://dbpedia.org/resource/Stockholm       3       NaN       NaN
# 16            http://dbpedia.org/resource/Moscow       2    Moscow  1.410590
# 17              http://dbpedia.org/resource/Oslo       2       NaN       NaN
# 18             http://dbpedia.org/resource/Sofia       2       NaN       NaN
# 19          http://dbpedia.org/resource/Valletta       2       NaN       NaN
# 20            http://dbpedia.org/resource/Athens       1       NaN       NaN
# 21         http://dbpedia.org/resource/Barcelona       1       NaN       NaN
# 22            http://dbpedia.org/resource/Prague       1       NaN       NaN
# 23          http://dbpedia.org/resource/Budapest       1  Budapest  0.500974
# 24             http://dbpedia.org/resource/Minsk       1       NaN       NaN
# 25             http://dbpedia.org/resource/Milan       1       NaN       NaN
# 26          http://dbpedia.org/resource/Tórshavn       1       NaN       NaN
# 27           http://dbpedia.org/resource/Belfast       1       NaN       NaN
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1           NaN       NaN
# 2      2.675248  5.688451
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14     1.629269  0.799474
# 15          NaN       NaN
# 16     2.198230  1.356614
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23     1.541863  0.592214
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN

# %%
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=10, opt='n')

#precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_european_capital_cities, euCap_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 10
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 1
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 2
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 52
# DBpedia entries taken: top 5
# Entries in the gold standard: 28
# -------------------------------------
# HITS: 5
# P@10: 1.0
# =====================================
#                                         resource  amount    name    degree  \
# 0             http://dbpedia.org/resource/Berlin      84     NaN       NaN
# 1              http://dbpedia.org/resource/Paris      74   Paris  2.174713
# 2             http://dbpedia.org/resource/London      45  London  5.766493
# 3               http://dbpedia.org/resource/Rome      29    Rome  1.090678
# 4             http://dbpedia.org/resource/Madrid      19     NaN       NaN
# 5             http://dbpedia.org/resource/Vienna       9     NaN       NaN
# 6   http://dbpedia.org/resource/City_of_Brussels       8     NaN       NaN
# 7             http://dbpedia.org/resource/Warsaw       7     NaN       NaN
# 8         http://dbpedia.org/resource/Copenhagen       7     NaN       NaN
# 9           http://dbpedia.org/resource/Helsinki       5     NaN       NaN
# 10         http://dbpedia.org/resource/Amsterdam       5     NaN       NaN
# 11            http://dbpedia.org/resource/Lisbon       4     NaN       NaN
# 12              http://dbpedia.org/resource/Kyiv       4     NaN       NaN
# 13         http://dbpedia.org/resource/Reykjavík       3     NaN       NaN
# 14            http://dbpedia.org/resource/Dublin       3  Dublin  0.786804
# 15         http://dbpedia.org/resource/Stockholm       3     NaN       NaN
# 16            http://dbpedia.org/resource/Moscow       2  Moscow  1.410590
# 17              http://dbpedia.org/resource/Oslo       2     NaN       NaN
# 18             http://dbpedia.org/resource/Sofia       2     NaN       NaN
# 19          http://dbpedia.org/resource/Valletta       2     NaN       NaN
# 20            http://dbpedia.org/resource/Athens       1     NaN       NaN
# 21         http://dbpedia.org/resource/Barcelona       1     NaN       NaN
# 22            http://dbpedia.org/resource/Prague       1     NaN       NaN
# 23          http://dbpedia.org/resource/Budapest       1     NaN       NaN
# 24             http://dbpedia.org/resource/Minsk       1     NaN       NaN
# 25             http://dbpedia.org/resource/Milan       1     NaN       NaN
# 26          http://dbpedia.org/resource/Tórshavn       1     NaN       NaN
# 27           http://dbpedia.org/resource/Belfast       1     NaN       NaN
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      0.671928  2.264122
# 2      2.675248  5.688451
# 3      0.751011  1.083243
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14     1.629269  0.799474
# 15          NaN       NaN
# 16     2.198230  1.356614
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN

# %% [markdown]
# ### European countries

# %%
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=10, opt='n')

#precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 10
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 8
# P@10: 0.8
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 2
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@10: 0.8
# =====================================
#                                            resource  amount            name  \
# 0               http://dbpedia.org/resource/Germany      80             NaN
# 1                http://dbpedia.org/resource/France      66          France
# 2                 http://dbpedia.org/resource/Italy      38           Italy
# 3                 http://dbpedia.org/resource/Spain      30             NaN
# 4        http://dbpedia.org/resource/United_Kingdom      13  United Kingdom
# 5                http://dbpedia.org/resource/Poland      13          Poland
# 6               http://dbpedia.org/resource/Austria      12             NaN
# 7                http://dbpedia.org/resource/Sweden      11             NaN
# 8           http://dbpedia.org/resource/Switzerland      11             NaN
# 9               http://dbpedia.org/resource/Denmark      10             NaN
# 10              http://dbpedia.org/resource/Ukraine       6             NaN
# 11             http://dbpedia.org/resource/Portugal       3             NaN
# 12  http://dbpedia.org/resource/Republic_of_Ireland       3             NaN
# 13               http://dbpedia.org/resource/Greece       3             NaN
# 14          http://dbpedia.org/resource/Netherlands       3             NaN
# 15              http://dbpedia.org/resource/Iceland       3             NaN
# 16               http://dbpedia.org/resource/Norway       3             NaN
# 17              http://dbpedia.org/resource/Belgium       3             NaN
# 18              http://dbpedia.org/resource/Croatia       2             NaN
# 19              http://dbpedia.org/resource/Romania       2             NaN
# 20         http://dbpedia.org/resource/Vatican_City       1             NaN
# 21           http://dbpedia.org/resource/San_Marino       1             NaN
# 22             http://dbpedia.org/resource/Slovenia       1             NaN
# 23               http://dbpedia.org/resource/Monaco       1             NaN
# 24           http://dbpedia.org/resource/Luxembourg       1             NaN
# 25             http://dbpedia.org/resource/Bulgaria       1             NaN
# 26             http://dbpedia.org/resource/Slovakia       1             NaN
# 27                http://dbpedia.org/resource/Malta       1             NaN
# 28            http://dbpedia.org/resource/Lithuania       1             NaN
#
#       degree  eigenvector  pagerank
# 0        NaN          NaN       NaN
# 1   3.424141     1.017289  4.113717
# 2   1.405014     4.885709  1.531766
# 3        NaN          NaN       NaN
# 4   3.299405    -0.754920  3.433746
# 5   3.571259     1.425449  2.692511
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23       NaN          NaN       NaN
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28       NaN          NaN       NaN

# %%
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=10, opt='n')

#precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 10
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 8
# P@10: 0.8
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 2
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@10: 0.8
# =====================================
#                                            resource  amount     name  \
# 0               http://dbpedia.org/resource/Germany      80      NaN
# 1                http://dbpedia.org/resource/France      66      NaN
# 2                 http://dbpedia.org/resource/Italy      38    Italy
# 3                 http://dbpedia.org/resource/Spain      30    Spain
# 4        http://dbpedia.org/resource/United_Kingdom      13      NaN
# 5                http://dbpedia.org/resource/Poland      13   Poland
# 6               http://dbpedia.org/resource/Austria      12      NaN
# 7                http://dbpedia.org/resource/Sweden      11      NaN
# 8           http://dbpedia.org/resource/Switzerland      11      NaN
# 9               http://dbpedia.org/resource/Denmark      10      NaN
# 10              http://dbpedia.org/resource/Ukraine       6      NaN
# 11             http://dbpedia.org/resource/Portugal       3      NaN
# 12  http://dbpedia.org/resource/Republic_of_Ireland       3      NaN
# 13               http://dbpedia.org/resource/Greece       3      NaN
# 14          http://dbpedia.org/resource/Netherlands       3      NaN
# 15              http://dbpedia.org/resource/Iceland       3      NaN
# 16               http://dbpedia.org/resource/Norway       3      NaN
# 17              http://dbpedia.org/resource/Belgium       3      NaN
# 18              http://dbpedia.org/resource/Croatia       2      NaN
# 19              http://dbpedia.org/resource/Romania       2  Romania
# 20         http://dbpedia.org/resource/Vatican_City       1      NaN
# 21           http://dbpedia.org/resource/San_Marino       1      NaN
# 22             http://dbpedia.org/resource/Slovenia       1      NaN
# 23               http://dbpedia.org/resource/Monaco       1      NaN
# 24           http://dbpedia.org/resource/Luxembourg       1      NaN
# 25             http://dbpedia.org/resource/Bulgaria       1      NaN
# 26             http://dbpedia.org/resource/Slovakia       1      NaN
# 27                http://dbpedia.org/resource/Malta       1      NaN
# 28            http://dbpedia.org/resource/Lithuania       1      NaN
#
#       degree  eigenvector  pagerank
# 0        NaN          NaN       NaN
# 1        NaN          NaN       NaN
# 2   1.405014     4.885709  1.531766
# 3   0.789731     2.224985  0.731091
# 4        NaN          NaN       NaN
# 5   3.571259     1.425449  2.692511
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19 -0.304779     1.403748 -0.282078
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23       NaN          NaN       NaN
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28       NaN          NaN       NaN

# %%
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=10, opt='n')

#precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_european_countries, euCou_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 10
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 8
# P@10: 0.8
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 1
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 2
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 51
# DBpedia entries taken: top 5
# Entries in the gold standard: 29
# -------------------------------------
# HITS: 4
# P@10: 0.8
# =====================================
#                                            resource  amount            name  \
# 0               http://dbpedia.org/resource/Germany      80             NaN
# 1                http://dbpedia.org/resource/France      66          France
# 2                 http://dbpedia.org/resource/Italy      38           Italy
# 3                 http://dbpedia.org/resource/Spain      30             NaN
# 4        http://dbpedia.org/resource/United_Kingdom      13  United Kingdom
# 5                http://dbpedia.org/resource/Poland      13          Poland
# 6               http://dbpedia.org/resource/Austria      12             NaN
# 7                http://dbpedia.org/resource/Sweden      11             NaN
# 8           http://dbpedia.org/resource/Switzerland      11             NaN
# 9               http://dbpedia.org/resource/Denmark      10             NaN
# 10              http://dbpedia.org/resource/Ukraine       6             NaN
# 11             http://dbpedia.org/resource/Portugal       3             NaN
# 12  http://dbpedia.org/resource/Republic_of_Ireland       3             NaN
# 13               http://dbpedia.org/resource/Greece       3             NaN
# 14          http://dbpedia.org/resource/Netherlands       3             NaN
# 15              http://dbpedia.org/resource/Iceland       3             NaN
# 16               http://dbpedia.org/resource/Norway       3             NaN
# 17              http://dbpedia.org/resource/Belgium       3             NaN
# 18              http://dbpedia.org/resource/Croatia       2             NaN
# 19              http://dbpedia.org/resource/Romania       2             NaN
# 20         http://dbpedia.org/resource/Vatican_City       1             NaN
# 21           http://dbpedia.org/resource/San_Marino       1             NaN
# 22             http://dbpedia.org/resource/Slovenia       1             NaN
# 23               http://dbpedia.org/resource/Monaco       1             NaN
# 24           http://dbpedia.org/resource/Luxembourg       1             NaN
# 25             http://dbpedia.org/resource/Bulgaria       1             NaN
# 26             http://dbpedia.org/resource/Slovakia       1             NaN
# 27                http://dbpedia.org/resource/Malta       1             NaN
# 28            http://dbpedia.org/resource/Lithuania       1             NaN
#
#       degree  eigenvector  pagerank
# 0        NaN          NaN       NaN
# 1   3.424141     1.017289  4.113717
# 2   1.405014     4.885709  1.531766
# 3        NaN          NaN       NaN
# 4   3.299405    -0.754920  3.433746
# 5   3.571259     1.425449  2.692511
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23       NaN          NaN       NaN
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28       NaN          NaN       NaN

# %% [markdown]
# ### Asian countries

# %%
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=10, opt='n')

#precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 10
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 2
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@10: 1.0
# =====================================
#                                          resource  amount    name    degree  \
# 0               http://dbpedia.org/resource/China      83     NaN       NaN
# 1               http://dbpedia.org/resource/Japan      61   Japan  1.190795
# 2               http://dbpedia.org/resource/India      25   India  4.757256
# 3         http://dbpedia.org/resource/South_Korea      24     NaN       NaN
# 4            http://dbpedia.org/resource/Thailand      23     NaN       NaN
# 5             http://dbpedia.org/resource/Vietnam      20     NaN       NaN
# 6           http://dbpedia.org/resource/Indonesia      16     NaN       NaN
# 7           http://dbpedia.org/resource/Singapore       9     NaN       NaN
# 8              http://dbpedia.org/resource/Taiwan       9     NaN       NaN
# 9            http://dbpedia.org/resource/Cambodia       6     NaN       NaN
# 10             http://dbpedia.org/resource/Russia       5  Russia  2.305223
# 11           http://dbpedia.org/resource/Mongolia       4     NaN       NaN
# 12           http://dbpedia.org/resource/Pakistan       4     NaN       NaN
# 13           http://dbpedia.org/resource/Malaysia       3     NaN       NaN
# 14               http://dbpedia.org/resource/Laos       3     NaN       NaN
# 15            http://dbpedia.org/resource/Myanmar       3     NaN       NaN
# 16          http://dbpedia.org/resource/Hong_Kong       2     NaN       NaN
# 17        http://dbpedia.org/resource/Philippines       2     NaN       NaN
# 18          http://dbpedia.org/resource/Sri_Lanka       2     NaN       NaN
# 19         http://dbpedia.org/resource/Kazakhstan       2     NaN       NaN
# 20              http://dbpedia.org/resource/Nepal       2     NaN       NaN
# 21              http://dbpedia.org/resource/Macau       1     NaN       NaN
# 22         http://dbpedia.org/resource/Bangladesh       1     NaN       NaN
# 23              http://dbpedia.org/resource/Hunan       1     NaN       NaN
# 24  http://dbpedia.org/resource/Peking_University       1     NaN       NaN
# 25           http://dbpedia.org/resource/Shanghai       1     NaN       NaN
# 26             http://dbpedia.org/resource/Mumbai       1     NaN       NaN
# 27             http://dbpedia.org/resource/Israel       1     NaN       NaN
# 28        http://dbpedia.org/resource/North_Korea       1     NaN       NaN
# 29        http://dbpedia.org/resource/Turgay_Avcı       1     NaN       NaN
# 30              http://dbpedia.org/resource/Syria       1     NaN       NaN
# 31             http://dbpedia.org/resource/Turkey       1  Turkey  1.096489
# 32               http://dbpedia.org/resource/Iran       1    Iran  3.978066
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      4.319159  1.516850
# 2      0.166922  5.022889
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10     2.663452  2.660033
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN
# 28          NaN       NaN
# 29          NaN       NaN
# 30          NaN       NaN
# 31     1.907186  1.115382
# 32     1.903508  3.071677

# %%
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=10, opt='n')

#precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 10
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 8
# P@10: 0.8
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 2
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@10: 1.0
# =====================================
#                                          resource  amount      name    degree  \
# 0               http://dbpedia.org/resource/China      83       NaN       NaN
# 1               http://dbpedia.org/resource/Japan      61     Japan  1.190795
# 2               http://dbpedia.org/resource/India      25       NaN       NaN
# 3         http://dbpedia.org/resource/South_Korea      24       NaN       NaN
# 4            http://dbpedia.org/resource/Thailand      23  Thailand -0.041661
# 5             http://dbpedia.org/resource/Vietnam      20       NaN       NaN
# 6           http://dbpedia.org/resource/Indonesia      16       NaN       NaN
# 7           http://dbpedia.org/resource/Singapore       9       NaN       NaN
# 8              http://dbpedia.org/resource/Taiwan       9       NaN       NaN
# 9            http://dbpedia.org/resource/Cambodia       6       NaN       NaN
# 10             http://dbpedia.org/resource/Russia       5    Russia  2.305223
# 11           http://dbpedia.org/resource/Mongolia       4       NaN       NaN
# 12           http://dbpedia.org/resource/Pakistan       4       NaN       NaN
# 13           http://dbpedia.org/resource/Malaysia       3       NaN       NaN
# 14               http://dbpedia.org/resource/Laos       3       NaN       NaN
# 15            http://dbpedia.org/resource/Myanmar       3       NaN       NaN
# 16          http://dbpedia.org/resource/Hong_Kong       2       NaN       NaN
# 17        http://dbpedia.org/resource/Philippines       2       NaN       NaN
# 18          http://dbpedia.org/resource/Sri_Lanka       2       NaN       NaN
# 19         http://dbpedia.org/resource/Kazakhstan       2       NaN       NaN
# 20              http://dbpedia.org/resource/Nepal       2       NaN       NaN
# 21              http://dbpedia.org/resource/Macau       1       NaN       NaN
# 22         http://dbpedia.org/resource/Bangladesh       1       NaN       NaN
# 23              http://dbpedia.org/resource/Hunan       1       NaN       NaN
# 24  http://dbpedia.org/resource/Peking_University       1       NaN       NaN
# 25           http://dbpedia.org/resource/Shanghai       1       NaN       NaN
# 26             http://dbpedia.org/resource/Mumbai       1       NaN       NaN
# 27             http://dbpedia.org/resource/Israel       1       NaN       NaN
# 28        http://dbpedia.org/resource/North_Korea       1       NaN       NaN
# 29        http://dbpedia.org/resource/Turgay_Avcı       1       NaN       NaN
# 30              http://dbpedia.org/resource/Syria       1       NaN       NaN
# 31             http://dbpedia.org/resource/Turkey       1    Turkey  1.096489
# 32               http://dbpedia.org/resource/Iran       1      Iran  3.978066
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      4.319159  1.516850
# 2           NaN       NaN
# 3           NaN       NaN
# 4      1.771082 -0.002353
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10     2.663452  2.660033
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN
# 28          NaN       NaN
# 29          NaN       NaN
# 30          NaN       NaN
# 31     1.907186  1.115382
# 32     1.903508  3.071677

# %%
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=10, opt='n')

#precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_asian_countries, asCou_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 10
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 10
# P@10: 1.0
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 1
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 1
# P@2: 1.0
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 2
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 2
# P@5: 1.0
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 53
# DBpedia entries taken: top 5
# Entries in the gold standard: 33
# -------------------------------------
# HITS: 5
# P@10: 1.0
# =====================================
#                                          resource  amount    name    degree  \
# 0               http://dbpedia.org/resource/China      83     NaN       NaN
# 1               http://dbpedia.org/resource/Japan      61   Japan  1.190795
# 2               http://dbpedia.org/resource/India      25   India  4.757256
# 3         http://dbpedia.org/resource/South_Korea      24     NaN       NaN
# 4            http://dbpedia.org/resource/Thailand      23     NaN       NaN
# 5             http://dbpedia.org/resource/Vietnam      20     NaN       NaN
# 6           http://dbpedia.org/resource/Indonesia      16     NaN       NaN
# 7           http://dbpedia.org/resource/Singapore       9     NaN       NaN
# 8              http://dbpedia.org/resource/Taiwan       9     NaN       NaN
# 9            http://dbpedia.org/resource/Cambodia       6     NaN       NaN
# 10             http://dbpedia.org/resource/Russia       5  Russia  2.305223
# 11           http://dbpedia.org/resource/Mongolia       4     NaN       NaN
# 12           http://dbpedia.org/resource/Pakistan       4     NaN       NaN
# 13           http://dbpedia.org/resource/Malaysia       3     NaN       NaN
# 14               http://dbpedia.org/resource/Laos       3     NaN       NaN
# 15            http://dbpedia.org/resource/Myanmar       3     NaN       NaN
# 16          http://dbpedia.org/resource/Hong_Kong       2     NaN       NaN
# 17        http://dbpedia.org/resource/Philippines       2     NaN       NaN
# 18          http://dbpedia.org/resource/Sri_Lanka       2     NaN       NaN
# 19         http://dbpedia.org/resource/Kazakhstan       2     NaN       NaN
# 20              http://dbpedia.org/resource/Nepal       2     NaN       NaN
# 21              http://dbpedia.org/resource/Macau       1     NaN       NaN
# 22         http://dbpedia.org/resource/Bangladesh       1     NaN       NaN
# 23              http://dbpedia.org/resource/Hunan       1     NaN       NaN
# 24  http://dbpedia.org/resource/Peking_University       1     NaN       NaN
# 25           http://dbpedia.org/resource/Shanghai       1     NaN       NaN
# 26             http://dbpedia.org/resource/Mumbai       1     NaN       NaN
# 27             http://dbpedia.org/resource/Israel       1     NaN       NaN
# 28        http://dbpedia.org/resource/North_Korea       1     NaN       NaN
# 29        http://dbpedia.org/resource/Turgay_Avcı       1     NaN       NaN
# 30              http://dbpedia.org/resource/Syria       1     NaN       NaN
# 31             http://dbpedia.org/resource/Turkey       1  Turkey  1.096489
# 32               http://dbpedia.org/resource/Iran       1    Iran  3.978066
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1      4.319159  1.516850
# 2      0.166922  5.022889
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10     2.663452  2.660033
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN
# 28          NaN       NaN
# 29          NaN       NaN
# 30          NaN       NaN
# 31     1.907186  1.115382
# 32     1.903508  3.071677

# %% [markdown]
# ### Continents

# %%
precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=10, opt='n')

#precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=1, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=2, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_continents, continents_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 5
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 10
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 7
# P@10: 0.7
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@10: 1.0
# =====================================
#                                             resource  amount        name  \
# 0                 http://dbpedia.org/resource/Europe      94         NaN
# 1                 http://dbpedia.org/resource/Africa      77         NaN
# 2                   http://dbpedia.org/resource/Asia      77         NaN
# 3          http://dbpedia.org/resource/North_America      34         NaN
# 4  http://dbpedia.org/resource/Australia_(continent)      23         NaN
# 5          http://dbpedia.org/resource/South_America      11         NaN
# 6             http://dbpedia.org/resource/Antarctica       6  Antarctica
# 7                http://dbpedia.org/resource/Oceania       1         NaN
#
#      degree  eigenvector  pagerank
# 0       NaN          NaN       NaN
# 1       NaN          NaN       NaN
# 2       NaN          NaN       NaN
# 3       NaN          NaN       NaN
# 4       NaN          NaN       NaN
# 5       NaN          NaN       NaN
# 6  3.644978    -0.433297  3.667496
# 7       NaN          NaN       NaN

# %%
precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=10, opt='n')

#precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=1, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=2, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_continents, continents_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 5
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 10
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 6
# P@10: 0.6
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@10: 1.0
# =====================================
#                                             resource  amount           name  \
# 0                 http://dbpedia.org/resource/Europe      94            NaN
# 1                 http://dbpedia.org/resource/Africa      77            NaN
# 2                   http://dbpedia.org/resource/Asia      77            NaN
# 3          http://dbpedia.org/resource/North_America      34            NaN
# 4  http://dbpedia.org/resource/Australia_(continent)      23            NaN
# 5          http://dbpedia.org/resource/South_America      11  South America
# 6             http://dbpedia.org/resource/Antarctica       6            NaN
# 7                http://dbpedia.org/resource/Oceania       1            NaN
#
#      degree  eigenvector  pagerank
# 0       NaN          NaN       NaN
# 1       NaN          NaN       NaN
# 2       NaN          NaN       NaN
# 3       NaN          NaN       NaN
# 4       NaN          NaN       NaN
# 5 -0.241534     3.639627 -0.252906
# 6       NaN          NaN       NaN
# 7       NaN          NaN       NaN

# %%
precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=10, opt='n')

#precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=1, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=2, opt='p')
#precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_continents, continents_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 5
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 5
# P@5: 1.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 10
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 7
# P@10: 0.7
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 15
# DBpedia entries taken: top 1
# Entries in the gold standard: 8
# -------------------------------------
# HITS: 1
# P@10: 1.0
# =====================================
#                                             resource  amount        name  \
# 0                 http://dbpedia.org/resource/Europe      94         NaN
# 1                 http://dbpedia.org/resource/Africa      77         NaN
# 2                   http://dbpedia.org/resource/Asia      77         NaN
# 3          http://dbpedia.org/resource/North_America      34         NaN
# 4  http://dbpedia.org/resource/Australia_(continent)      23         NaN
# 5          http://dbpedia.org/resource/South_America      11         NaN
# 6             http://dbpedia.org/resource/Antarctica       6  Antarctica
# 7                http://dbpedia.org/resource/Oceania       1         NaN
#
#      degree  eigenvector  pagerank
# 0       NaN          NaN       NaN
# 1       NaN          NaN       NaN
# 2       NaN          NaN       NaN
# 3       NaN          NaN       NaN
# 4       NaN          NaN       NaN
# 5       NaN          NaN       NaN
# 6  3.644978    -0.433297  3.667496
# 7       NaN          NaN       NaN

# %% [markdown]
# ### Birds

# %%
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 1
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 5
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 1
# P@5: 0.2
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 10
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 1
# P@10: 0.1
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 33
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 1
# P@1: 0.030303030303030304
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 66
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 3
# P@2: 0.045454545454545456
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 166
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 3
# P@5: 0.018072289156626505
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 332
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 4
# P@10: 0.012048192771084338
# =====================================
#                                            resource  amount             name  \
# 0                 http://dbpedia.org/resource/Eagle      45            Eagle
# 1               http://dbpedia.org/resource/Sparrow      22              NaN
# 2      http://dbpedia.org/resource/Common_blackbird      19              NaN
# 3                 http://dbpedia.org/resource/Robin      18              NaN
# 4            http://dbpedia.org/resource/Columbidae      15              NaN
# 5           http://dbpedia.org/resource/Hummingbird      12              NaN
# 6                   http://dbpedia.org/resource/Owl      10              NaN
# 7                  http://dbpedia.org/resource/Crow      10              NaN
# 8                http://dbpedia.org/resource/Parrot      10              NaN
# 9                 http://dbpedia.org/resource/Raven       9              NaN
# 10                 http://dbpedia.org/resource/Gull       8              NaN
# 11           http://dbpedia.org/resource/Tit_(bird)       7              NaN
# 12          http://dbpedia.org/resource/Mockingbird       7              NaN
# 13              http://dbpedia.org/resource/Chicken       7          Chicken
# 14                http://dbpedia.org/resource/Finch       7              NaN
# 15               http://dbpedia.org/resource/Falcon       6              NaN
# 16   http://dbpedia.org/resource/Common_nightingale       6              NaN
# 17              http://dbpedia.org/resource/Penguin       5              NaN
# 18               http://dbpedia.org/resource/Magpie       5              NaN
# 19                http://dbpedia.org/resource/Stork       5              NaN
# 20              http://dbpedia.org/resource/Swallow       4              NaN
# 21           http://dbpedia.org/resource/Budgerigar       4              NaN
# 22              http://dbpedia.org/resource/Vulture       4              NaN
# 23                 http://dbpedia.org/resource/Duck       4             Duck
# 24        http://dbpedia.org/resource/Thrush_(bird)       4              NaN
# 25         http://dbpedia.org/resource/Crane_(bird)       3              NaN
# 26    http://dbpedia.org/resource/Eurasian_blue_tit       3              NaN
# 27                 http://dbpedia.org/resource/Swan       3              NaN
# 28      http://dbpedia.org/resource/Cardinal_(bird)       3  Cardinal (bird)
# 29              http://dbpedia.org/resource/Ostrich       3              NaN
# 30              http://dbpedia.org/resource/Pelican       3              NaN
# 31                 http://dbpedia.org/resource/Hawk       2              NaN
# 32          http://dbpedia.org/resource/Kiwi_(bird)       2              NaN
# 33                http://dbpedia.org/resource/Buteo       2              NaN
# 34             http://dbpedia.org/resource/Parakeet       2              NaN
# 35                http://dbpedia.org/resource/Goose       1              NaN
# 36           http://dbpedia.org/resource/Kookaburra       1              NaN
# 37                 http://dbpedia.org/resource/Wren       1              NaN
# 38              http://dbpedia.org/resource/Peafowl       1              NaN
# 39    http://dbpedia.org/resource/Common_chiffchaff       1              NaN
# 40              http://dbpedia.org/resource/Pidgeon       1              NaN
# 41    http://dbpedia.org/resource/Common_kingfisher       1              NaN
# 42  http://dbpedia.org/resource/Pileated_woodpecker       1              NaN
# 43            http://dbpedia.org/resource/Albatross       1              NaN
# 44     http://dbpedia.org/resource/Common_chaffinch       1              NaN
# 45           http://dbpedia.org/resource/Ara_(bird)       1              NaN
# 46             http://dbpedia.org/resource/Whinchat       1              NaN
# 47             http://dbpedia.org/resource/Red_kite       1              NaN
# 48               http://dbpedia.org/resource/Cuckoo       1              NaN
# 49             http://dbpedia.org/resource/Flamingo       1              NaN
#
#       degree  eigenvector  pagerank
# 0   1.633233    -0.057304  1.563316
# 1        NaN          NaN       NaN
# 2        NaN          NaN       NaN
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13  7.578503    -0.030527  7.402554
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23  1.343220    -0.031070  1.564309
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28  0.473180    -0.031072  0.512651
# 29       NaN          NaN       NaN
# 30       NaN          NaN       NaN
# 31       NaN          NaN       NaN
# 32       NaN          NaN       NaN
# 33       NaN          NaN       NaN
# 34       NaN          NaN       NaN
# 35       NaN          NaN       NaN
# 36       NaN          NaN       NaN
# 37       NaN          NaN       NaN
# 38       NaN          NaN       NaN
# 39       NaN          NaN       NaN
# 40       NaN          NaN       NaN
# 41       NaN          NaN       NaN
# 42       NaN          NaN       NaN
# 43       NaN          NaN       NaN
# 44       NaN          NaN       NaN
# 45       NaN          NaN       NaN
# 46       NaN          NaN       NaN
# 47       NaN          NaN       NaN
# 48       NaN          NaN       NaN
# 49       NaN          NaN       NaN

# %%
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 1
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 5
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 10
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 33
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 66
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@2: 0.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 166
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 5
# P@5: 0.030120481927710843
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 332
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 10
# P@10: 0.030120481927710843
# =====================================
#                                            resource  amount             name  \
# 0                 http://dbpedia.org/resource/Eagle      45              NaN
# 1               http://dbpedia.org/resource/Sparrow      22              NaN
# 2      http://dbpedia.org/resource/Common_blackbird      19              NaN
# 3                 http://dbpedia.org/resource/Robin      18              NaN
# 4            http://dbpedia.org/resource/Columbidae      15              NaN
# 5           http://dbpedia.org/resource/Hummingbird      12              NaN
# 6                   http://dbpedia.org/resource/Owl      10              NaN
# 7                  http://dbpedia.org/resource/Crow      10              NaN
# 8                http://dbpedia.org/resource/Parrot      10              NaN
# 9                 http://dbpedia.org/resource/Raven       9            Raven
# 10                 http://dbpedia.org/resource/Gull       8              NaN
# 11           http://dbpedia.org/resource/Tit_(bird)       7              NaN
# 12          http://dbpedia.org/resource/Mockingbird       7              NaN
# 13              http://dbpedia.org/resource/Chicken       7          Chicken
# 14                http://dbpedia.org/resource/Finch       7            Finch
# 15               http://dbpedia.org/resource/Falcon       6              NaN
# 16   http://dbpedia.org/resource/Common_nightingale       6              NaN
# 17              http://dbpedia.org/resource/Penguin       5              NaN
# 18               http://dbpedia.org/resource/Magpie       5              NaN
# 19                http://dbpedia.org/resource/Stork       5              NaN
# 20              http://dbpedia.org/resource/Swallow       4              NaN
# 21           http://dbpedia.org/resource/Budgerigar       4              NaN
# 22              http://dbpedia.org/resource/Vulture       4              NaN
# 23                 http://dbpedia.org/resource/Duck       4             Duck
# 24        http://dbpedia.org/resource/Thrush_(bird)       4              NaN
# 25         http://dbpedia.org/resource/Crane_(bird)       3              NaN
# 26    http://dbpedia.org/resource/Eurasian_blue_tit       3              NaN
# 27                 http://dbpedia.org/resource/Swan       3              NaN
# 28      http://dbpedia.org/resource/Cardinal_(bird)       3  Cardinal (bird)
# 29              http://dbpedia.org/resource/Ostrich       3              NaN
# 30              http://dbpedia.org/resource/Pelican       3              NaN
# 31                 http://dbpedia.org/resource/Hawk       2              NaN
# 32          http://dbpedia.org/resource/Kiwi_(bird)       2      Kiwi (bird)
# 33                http://dbpedia.org/resource/Buteo       2              NaN
# 34             http://dbpedia.org/resource/Parakeet       2              NaN
# 35                http://dbpedia.org/resource/Goose       1              NaN
# 36           http://dbpedia.org/resource/Kookaburra       1              NaN
# 37                 http://dbpedia.org/resource/Wren       1             Wren
# 38              http://dbpedia.org/resource/Peafowl       1          Peafowl
# 39    http://dbpedia.org/resource/Common_chiffchaff       1              NaN
# 40              http://dbpedia.org/resource/Pidgeon       1              NaN
# 41    http://dbpedia.org/resource/Common_kingfisher       1              NaN
# 42  http://dbpedia.org/resource/Pileated_woodpecker       1              NaN
# 43            http://dbpedia.org/resource/Albatross       1        Albatross
# 44     http://dbpedia.org/resource/Common_chaffinch       1              NaN
# 45           http://dbpedia.org/resource/Ara_(bird)       1              NaN
# 46             http://dbpedia.org/resource/Whinchat       1              NaN
# 47             http://dbpedia.org/resource/Red_kite       1              NaN
# 48               http://dbpedia.org/resource/Cuckoo       1              NaN
# 49             http://dbpedia.org/resource/Flamingo       1         Flamingo
#
#       degree  eigenvector  pagerank
# 0        NaN          NaN       NaN
# 1        NaN          NaN       NaN
# 2        NaN          NaN       NaN
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9  -0.106846    -0.031119 -0.058493
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13  7.578503    -0.030527  7.402554
# 14 -0.034343    -0.031132  0.010304
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23  1.343220    -0.031070  1.564309
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28  0.473180    -0.031072  0.512651
# 29       NaN          NaN       NaN
# 30       NaN          NaN       NaN
# 31       NaN          NaN       NaN
# 32 -0.179349    -0.031136 -0.064456
# 33       NaN          NaN       NaN
# 34       NaN          NaN       NaN
# 35       NaN          NaN       NaN
# 36       NaN          NaN       NaN
# 37 -0.251852    -0.031136 -0.180757
# 38 -0.179349    -0.031135 -0.024788
# 39       NaN          NaN       NaN
# 40       NaN          NaN       NaN
# 41       NaN          NaN       NaN
# 42       NaN          NaN       NaN
# 43 -0.179349    -0.031115  0.057158
# 44       NaN          NaN       NaN
# 45       NaN          NaN       NaN
# 46       NaN          NaN       NaN
# 47       NaN          NaN       NaN
# 48       NaN          NaN       NaN
# 49 -0.034343    -0.031114  0.190593

# %%
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_birds, birds_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 1
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 5
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 10
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 1
# P@10: 0.1
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 33
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 1
# P@1: 0.030303030303030304
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 66
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 3
# P@2: 0.045454545454545456
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 166
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 3
# P@5: 0.018072289156626505
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3323
# DBpedia entries taken: top 332
# Entries in the gold standard: 50
# -------------------------------------
# HITS: 4
# P@10: 0.012048192771084338
# =====================================
#                                            resource  amount             name  \
# 0                 http://dbpedia.org/resource/Eagle      45            Eagle
# 1               http://dbpedia.org/resource/Sparrow      22              NaN
# 2      http://dbpedia.org/resource/Common_blackbird      19              NaN
# 3                 http://dbpedia.org/resource/Robin      18              NaN
# 4            http://dbpedia.org/resource/Columbidae      15              NaN
# 5           http://dbpedia.org/resource/Hummingbird      12              NaN
# 6                   http://dbpedia.org/resource/Owl      10              NaN
# 7                  http://dbpedia.org/resource/Crow      10              NaN
# 8                http://dbpedia.org/resource/Parrot      10              NaN
# 9                 http://dbpedia.org/resource/Raven       9              NaN
# 10                 http://dbpedia.org/resource/Gull       8              NaN
# 11           http://dbpedia.org/resource/Tit_(bird)       7              NaN
# 12          http://dbpedia.org/resource/Mockingbird       7              NaN
# 13              http://dbpedia.org/resource/Chicken       7          Chicken
# 14                http://dbpedia.org/resource/Finch       7              NaN
# 15               http://dbpedia.org/resource/Falcon       6              NaN
# 16   http://dbpedia.org/resource/Common_nightingale       6              NaN
# 17              http://dbpedia.org/resource/Penguin       5              NaN
# 18               http://dbpedia.org/resource/Magpie       5              NaN
# 19                http://dbpedia.org/resource/Stork       5              NaN
# 20              http://dbpedia.org/resource/Swallow       4              NaN
# 21           http://dbpedia.org/resource/Budgerigar       4              NaN
# 22              http://dbpedia.org/resource/Vulture       4              NaN
# 23                 http://dbpedia.org/resource/Duck       4             Duck
# 24        http://dbpedia.org/resource/Thrush_(bird)       4              NaN
# 25         http://dbpedia.org/resource/Crane_(bird)       3              NaN
# 26    http://dbpedia.org/resource/Eurasian_blue_tit       3              NaN
# 27                 http://dbpedia.org/resource/Swan       3              NaN
# 28      http://dbpedia.org/resource/Cardinal_(bird)       3  Cardinal (bird)
# 29              http://dbpedia.org/resource/Ostrich       3              NaN
# 30              http://dbpedia.org/resource/Pelican       3              NaN
# 31                 http://dbpedia.org/resource/Hawk       2              NaN
# 32          http://dbpedia.org/resource/Kiwi_(bird)       2              NaN
# 33                http://dbpedia.org/resource/Buteo       2              NaN
# 34             http://dbpedia.org/resource/Parakeet       2              NaN
# 35                http://dbpedia.org/resource/Goose       1              NaN
# 36           http://dbpedia.org/resource/Kookaburra       1              NaN
# 37                 http://dbpedia.org/resource/Wren       1              NaN
# 38              http://dbpedia.org/resource/Peafowl       1              NaN
# 39    http://dbpedia.org/resource/Common_chiffchaff       1              NaN
# 40              http://dbpedia.org/resource/Pidgeon       1              NaN
# 41    http://dbpedia.org/resource/Common_kingfisher       1              NaN
# 42  http://dbpedia.org/resource/Pileated_woodpecker       1              NaN
# 43            http://dbpedia.org/resource/Albatross       1              NaN
# 44     http://dbpedia.org/resource/Common_chaffinch       1              NaN
# 45           http://dbpedia.org/resource/Ara_(bird)       1              NaN
# 46             http://dbpedia.org/resource/Whinchat       1              NaN
# 47             http://dbpedia.org/resource/Red_kite       1              NaN
# 48               http://dbpedia.org/resource/Cuckoo       1              NaN
# 49             http://dbpedia.org/resource/Flamingo       1              NaN
#
#       degree  eigenvector  pagerank
# 0   1.633233    -0.057304  1.563316
# 1        NaN          NaN       NaN
# 2        NaN          NaN       NaN
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13  7.578503    -0.030527  7.402554
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23  1.343220    -0.031070  1.564309
# 24       NaN          NaN       NaN
# 25       NaN          NaN       NaN
# 26       NaN          NaN       NaN
# 27       NaN          NaN       NaN
# 28  0.473180    -0.031072  0.512651
# 29       NaN          NaN       NaN
# 30       NaN          NaN       NaN
# 31       NaN          NaN       NaN
# 32       NaN          NaN       NaN
# 33       NaN          NaN       NaN
# 34       NaN          NaN       NaN
# 35       NaN          NaN       NaN
# 36       NaN          NaN       NaN
# 37       NaN          NaN       NaN
# 38       NaN          NaN       NaN
# 39       NaN          NaN       NaN
# 40       NaN          NaN       NaN
# 41       NaN          NaN       NaN
# 42       NaN          NaN       NaN
# 43       NaN          NaN       NaN
# 44       NaN          NaN       NaN
# 45       NaN          NaN       NaN
# 46       NaN          NaN       NaN
# 47       NaN          NaN       NaN
# 48       NaN          NaN       NaN
# 49       NaN          NaN       NaN

# %% [markdown]
# ### African animals

# %%
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 1
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 5
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 10
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 13
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 27
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@2: 0.0
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 68
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 2
# P@5: 0.029411764705882353
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 137
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 3
# P@10: 0.021897810218978103
# =====================================
#                                           resource  amount      name  \
# 0                 http://dbpedia.org/resource/Lion      79      Lion
# 1             http://dbpedia.org/resource/Elephant      79  Elephant
# 2              http://dbpedia.org/resource/Giraffe      52       NaN
# 3                http://dbpedia.org/resource/Zebra      39       NaN
# 4           http://dbpedia.org/resource/Rhinoceros      10       NaN
# 5         http://dbpedia.org/resource/Hippopotamus       9       NaN
# 6             http://dbpedia.org/resource/Antelope       8       NaN
# 7                http://dbpedia.org/resource/Tiger       6       NaN
# 8                http://dbpedia.org/resource/Hyena       6       NaN
# 9              http://dbpedia.org/resource/Cheetah       4       NaN
# 10              http://dbpedia.org/resource/Monkey       4       NaN
# 11              http://dbpedia.org/resource/Cougar       3       NaN
# 12             http://dbpedia.org/resource/Leopard       3       NaN
# 13          http://dbpedia.org/resource/Wildebeest       3       NaN
# 14      http://dbpedia.org/resource/American_bison       3       NaN
# 15             http://dbpedia.org/resource/Gazelle       2       NaN
# 16  http://dbpedia.org/resource/American_alligator       2       NaN
# 17            http://dbpedia.org/resource/Scorpion       2       NaN
# 18               http://dbpedia.org/resource/Snake       1       NaN
# 19               http://dbpedia.org/resource/Camel       1       NaN
# 20         http://dbpedia.org/resource/Black_mamba       1       NaN
# 21              http://dbpedia.org/resource/Impala       1       NaN
# 22        http://dbpedia.org/resource/Honey_badger       1       NaN
# 23             http://dbpedia.org/resource/Gorilla       1   Gorilla
# 24           http://dbpedia.org/resource/Crocodile       1       NaN
#
#       degree  eigenvector  pagerank
# 0   1.675403     1.176816  2.352187
# 1   1.675403     1.107624  3.119400
# 2        NaN          NaN       NaN
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23  1.092255     1.100259  1.939385
# 24       NaN          NaN       NaN

# %%
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 1
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 5
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 10
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 13
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 1
# P@1: 0.07692307692307693
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 27
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 3
# P@2: 0.1111111111111111
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 68
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 6
# P@5: 0.08823529411764706
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 137
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 11
# P@10: 0.08029197080291971
# =====================================
#                                           resource  amount          name  \
# 0                 http://dbpedia.org/resource/Lion      79          Lion
# 1             http://dbpedia.org/resource/Elephant      79      Elephant
# 2              http://dbpedia.org/resource/Giraffe      52       Giraffe
# 3                http://dbpedia.org/resource/Zebra      39         Zebra
# 4           http://dbpedia.org/resource/Rhinoceros      10           NaN
# 5         http://dbpedia.org/resource/Hippopotamus       9  Hippopotamus
# 6             http://dbpedia.org/resource/Antelope       8           NaN
# 7                http://dbpedia.org/resource/Tiger       6           NaN
# 8                http://dbpedia.org/resource/Hyena       6           NaN
# 9              http://dbpedia.org/resource/Cheetah       4           NaN
# 10              http://dbpedia.org/resource/Monkey       4           NaN
# 11              http://dbpedia.org/resource/Cougar       3           NaN
# 12             http://dbpedia.org/resource/Leopard       3       Leopard
# 13          http://dbpedia.org/resource/Wildebeest       3    Wildebeest
# 14      http://dbpedia.org/resource/American_bison       3           NaN
# 15             http://dbpedia.org/resource/Gazelle       2           NaN
# 16  http://dbpedia.org/resource/American_alligator       2           NaN
# 17            http://dbpedia.org/resource/Scorpion       2           NaN
# 18               http://dbpedia.org/resource/Snake       1           NaN
# 19               http://dbpedia.org/resource/Camel       1           NaN
# 20         http://dbpedia.org/resource/Black_mamba       1   Black mamba
# 21              http://dbpedia.org/resource/Impala       1        Impala
# 22        http://dbpedia.org/resource/Honey_badger       1           NaN
# 23             http://dbpedia.org/resource/Gorilla       1       Gorilla
# 24           http://dbpedia.org/resource/Crocodile       1     Crocodile
#
#       degree  eigenvector  pagerank
# 0   1.675403     1.176816  2.352187
# 1   1.675403     1.107624  3.119400
# 2   0.159218     1.093225  0.905268
# 3  -0.190671     1.094520 -0.065516
# 4        NaN          NaN       NaN
# 5  -0.423930     1.092840 -0.322403
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12 -0.423930     1.094183 -0.148098
# 13 -0.423930     1.094185 -0.261663
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20 -0.307300     1.094450 -0.007247
# 21 -0.307300     1.094139 -0.060383
# 22       NaN          NaN       NaN
# 23  1.092255     1.100259  1.939385
# 24  0.392477     1.093208  0.595275

# %%
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_african_animals, africanAnimal_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 1
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 5
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 10
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 13
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 1
# P@1: 0.07692307692307693
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 27
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 2
# P@2: 0.07407407407407407
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 68
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 3
# P@5: 0.04411764705882353
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1372
# DBpedia entries taken: top 137
# Entries in the gold standard: 25
# -------------------------------------
# HITS: 4
# P@10: 0.029197080291970802
# =====================================
#                                           resource  amount      name  \
# 0                 http://dbpedia.org/resource/Lion      79      Lion
# 1             http://dbpedia.org/resource/Elephant      79  Elephant
# 2              http://dbpedia.org/resource/Giraffe      52   Giraffe
# 3                http://dbpedia.org/resource/Zebra      39       NaN
# 4           http://dbpedia.org/resource/Rhinoceros      10       NaN
# 5         http://dbpedia.org/resource/Hippopotamus       9       NaN
# 6             http://dbpedia.org/resource/Antelope       8       NaN
# 7                http://dbpedia.org/resource/Tiger       6       NaN
# 8                http://dbpedia.org/resource/Hyena       6       NaN
# 9              http://dbpedia.org/resource/Cheetah       4       NaN
# 10              http://dbpedia.org/resource/Monkey       4       NaN
# 11              http://dbpedia.org/resource/Cougar       3       NaN
# 12             http://dbpedia.org/resource/Leopard       3       NaN
# 13          http://dbpedia.org/resource/Wildebeest       3       NaN
# 14      http://dbpedia.org/resource/American_bison       3       NaN
# 15             http://dbpedia.org/resource/Gazelle       2       NaN
# 16  http://dbpedia.org/resource/American_alligator       2       NaN
# 17            http://dbpedia.org/resource/Scorpion       2       NaN
# 18               http://dbpedia.org/resource/Snake       1       NaN
# 19               http://dbpedia.org/resource/Camel       1       NaN
# 20         http://dbpedia.org/resource/Black_mamba       1       NaN
# 21              http://dbpedia.org/resource/Impala       1       NaN
# 22        http://dbpedia.org/resource/Honey_badger       1       NaN
# 23             http://dbpedia.org/resource/Gorilla       1   Gorilla
# 24           http://dbpedia.org/resource/Crocodile       1       NaN
#
#       degree  eigenvector  pagerank
# 0   1.675403     1.176816  2.352187
# 1   1.675403     1.107624  3.119400
# 2   0.159218     1.093225  0.905268
# 3        NaN          NaN       NaN
# 4        NaN          NaN       NaN
# 5        NaN          NaN       NaN
# 6        NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
# 12       NaN          NaN       NaN
# 13       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 15       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 18       NaN          NaN       NaN
# 19       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 21       NaN          NaN       NaN
# 22       NaN          NaN       NaN
# 23  1.092255     1.100259  1.939385
# 24       NaN          NaN       NaN

# %% [markdown]
# ### Vegetables

# %%
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 1
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 5
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 10
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 4
# P@10: 0.4
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 19
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 6
# P@1: 0.3157894736842105
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 38
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 11
# P@2: 0.2894736842105263
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 97
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 20
# P@5: 0.20618556701030927
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 194
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 22
# P@10: 0.1134020618556701
# =====================================
#                                        resource  amount         name  \
# 0            http://dbpedia.org/resource/Carrot      51       Carrot
# 1          http://dbpedia.org/resource/Cucumber      47     Cucumber
# 2            http://dbpedia.org/resource/Tomato      43       Tomato
# 3            http://dbpedia.org/resource/Potato      19       Potato
# 4          http://dbpedia.org/resource/Broccoli      18          NaN
# 5          http://dbpedia.org/resource/Zucchini      17     Zucchini
# 6          http://dbpedia.org/resource/Eggplant      17     Eggplant
# 7       http://dbpedia.org/resource/Bell_pepper      14  Bell pepper
# 8           http://dbpedia.org/resource/Paprika      11      Paprika
# 9             http://dbpedia.org/resource/Onion      11        Onion
# 10      http://dbpedia.org/resource/Cauliflower      10  Cauliflower
# 11         http://dbpedia.org/resource/Mushroom       7          NaN
# 12          http://dbpedia.org/resource/Lettuce       6      Lettuce
# 13             http://dbpedia.org/resource/Bean       5         Bean
# 14          http://dbpedia.org/resource/Spinach       5      Spinach
# 15             http://dbpedia.org/resource/Leek       3         Leek
# 16          http://dbpedia.org/resource/Pumpkin       3      Pumpkin
# 17           http://dbpedia.org/resource/Turnip       2          NaN
# 18          http://dbpedia.org/resource/Avocado       2          NaN
# 19            http://dbpedia.org/resource/Apple       2          NaN
# 20         http://dbpedia.org/resource/Beetroot       2          NaN
# 21              http://dbpedia.org/resource/Pea       2          Pea
# 22           http://dbpedia.org/resource/Celery       2       Celery
# 23        http://dbpedia.org/resource/Asparagus       2          NaN
# 24          http://dbpedia.org/resource/Cabbage       2      Cabbage
# 25        http://dbpedia.org/resource/Artichoke       1          NaN
# 26             http://dbpedia.org/resource/Kale       1         Kale
# 27             http://dbpedia.org/resource/Leak       1          NaN
# 28  http://dbpedia.org/resource/Brussels_sprout       1          NaN
# 29           http://dbpedia.org/resource/Radish       1          NaN
# 30           http://dbpedia.org/resource/Banana       1          NaN
# 31            http://dbpedia.org/resource/Mango       1          NaN
# 32            http://dbpedia.org/resource/Grape       1          NaN
# 33           http://dbpedia.org/resource/Lentil       1       Lentil
# 34         http://dbpedia.org/resource/Capsicum       1          NaN
# 35           http://dbpedia.org/resource/Garlic       1       Garlic
# 36       http://dbpedia.org/resource/Green_bean       1   Green bean
#
#        degree  eigenvector   pagerank
# 0    3.533501     0.324573   3.479786
# 1    1.754923     0.317726   1.737238
# 2   11.570037     0.348644  11.056798
# 3   18.486729     0.345457  19.924285
# 4         NaN          NaN        NaN
# 5    0.305712    -0.190943   0.419327
# 6    2.150163     0.320709   2.069660
# 7    2.413656    -0.187573   2.235934
# 8    0.832698    -0.189405   0.755452
# 9   21.385152     0.359892  20.336650
# 10   0.635078    -0.191314   0.846759
# 11        NaN          NaN        NaN
# 12   1.623177     0.318867   1.803452
# 13   2.545402     0.324451   2.698506
# 14   1.557303     0.320849   1.545486
# 15   1.754923    -0.188739   1.721750
# 16   0.964444     0.316749   1.037156
# 17        NaN          NaN        NaN
# 18        NaN          NaN        NaN
# 19        NaN          NaN        NaN
# 20        NaN          NaN        NaN
# 21   1.227937     0.316105   1.320733
# 22   1.162064     0.319338   1.118965
# 23        NaN          NaN        NaN
# 24   3.006515    -0.187026   3.032548
# 25        NaN          NaN        NaN
# 26   0.371585    -0.189814   0.651543
# 27        NaN          NaN        NaN
# 28        NaN          NaN        NaN
# 29        NaN          NaN        NaN
# 30        NaN          NaN        NaN
# 31        NaN          NaN        NaN
# 32        NaN          NaN        NaN
# 33   0.898571     0.315954   0.943952
# 34        NaN          NaN        NaN
# 35  12.887502     0.344445  12.135952
# 36   0.700951     0.316936   0.731472

# %%
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 1
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 5
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 10
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 19
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 38
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 0
# P@2: 0.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 97
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 11
# P@5: 0.1134020618556701
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 194
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 19
# P@10: 0.0979381443298969
# =====================================
#                                        resource  amount        name  \
# 0            http://dbpedia.org/resource/Carrot      51      Carrot
# 1          http://dbpedia.org/resource/Cucumber      47    Cucumber
# 2            http://dbpedia.org/resource/Tomato      43      Tomato
# 3            http://dbpedia.org/resource/Potato      19      Potato
# 4          http://dbpedia.org/resource/Broccoli      18    Broccoli
# 5          http://dbpedia.org/resource/Zucchini      17         NaN
# 6          http://dbpedia.org/resource/Eggplant      17    Eggplant
# 7       http://dbpedia.org/resource/Bell_pepper      14         NaN
# 8           http://dbpedia.org/resource/Paprika      11         NaN
# 9             http://dbpedia.org/resource/Onion      11       Onion
# 10      http://dbpedia.org/resource/Cauliflower      10         NaN
# 11         http://dbpedia.org/resource/Mushroom       7         NaN
# 12          http://dbpedia.org/resource/Lettuce       6     Lettuce
# 13             http://dbpedia.org/resource/Bean       5        Bean
# 14          http://dbpedia.org/resource/Spinach       5     Spinach
# 15             http://dbpedia.org/resource/Leek       3         NaN
# 16          http://dbpedia.org/resource/Pumpkin       3     Pumpkin
# 17           http://dbpedia.org/resource/Turnip       2      Turnip
# 18          http://dbpedia.org/resource/Avocado       2         NaN
# 19            http://dbpedia.org/resource/Apple       2         NaN
# 20         http://dbpedia.org/resource/Beetroot       2         NaN
# 21              http://dbpedia.org/resource/Pea       2         Pea
# 22           http://dbpedia.org/resource/Celery       2      Celery
# 23        http://dbpedia.org/resource/Asparagus       2         NaN
# 24          http://dbpedia.org/resource/Cabbage       2         NaN
# 25        http://dbpedia.org/resource/Artichoke       1   Artichoke
# 26             http://dbpedia.org/resource/Kale       1         NaN
# 27             http://dbpedia.org/resource/Leak       1         NaN
# 28  http://dbpedia.org/resource/Brussels_sprout       1         NaN
# 29           http://dbpedia.org/resource/Radish       1      Radish
# 30           http://dbpedia.org/resource/Banana       1         NaN
# 31            http://dbpedia.org/resource/Mango       1         NaN
# 32            http://dbpedia.org/resource/Grape       1         NaN
# 33           http://dbpedia.org/resource/Lentil       1      Lentil
# 34         http://dbpedia.org/resource/Capsicum       1         NaN
# 35           http://dbpedia.org/resource/Garlic       1      Garlic
# 36       http://dbpedia.org/resource/Green_bean       1  Green bean
#
#        degree  eigenvector   pagerank
# 0    3.533501     0.324573   3.479786
# 1    1.754923     0.317726   1.737238
# 2   11.570037     0.348644  11.056798
# 3   18.486729     0.345457  19.924285
# 4    0.108092     0.701546   0.166846
# 5         NaN          NaN        NaN
# 6    2.150163     0.320709   2.069660
# 7         NaN          NaN        NaN
# 8         NaN          NaN        NaN
# 9   21.385152     0.359892  20.336650
# 10        NaN          NaN        NaN
# 11        NaN          NaN        NaN
# 12   1.623177     0.318867   1.803452
# 13   2.545402     0.324451   2.698506
# 14   1.557303     0.320849   1.545486
# 15        NaN          NaN        NaN
# 16   0.964444     0.316749   1.037156
# 17   0.042219     0.315475   0.083433
# 18        NaN          NaN        NaN
# 19        NaN          NaN        NaN
# 20        NaN          NaN        NaN
# 21   1.227937     0.316105   1.320733
# 22   1.162064     0.319338   1.118965
# 23        NaN          NaN        NaN
# 24        NaN          NaN        NaN
# 25  -0.221274     0.315363  -0.119889
# 26        NaN          NaN        NaN
# 27        NaN          NaN        NaN
# 28        NaN          NaN        NaN
# 29   0.108092     0.315312   0.123537
# 30        NaN          NaN        NaN
# 31        NaN          NaN        NaN
# 32        NaN          NaN        NaN
# 33   0.898571     0.315954   0.943952
# 34        NaN          NaN        NaN
# 35  12.887502     0.344445  12.135952
# 36   0.700951     0.316936   0.731472

# %%
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_vegetables, vegetables_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 1
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 1
# P@1: 1.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 5
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 4
# P@5: 0.8
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 10
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 4
# P@10: 0.4
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 19
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 5
# P@1: 0.2631578947368421
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 38
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 11
# P@2: 0.2894736842105263
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 97
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 21
# P@5: 0.21649484536082475
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 1941
# DBpedia entries taken: top 194
# Entries in the gold standard: 37
# -------------------------------------
# HITS: 23
# P@10: 0.11855670103092783
# =====================================
#                                        resource  amount         name  \
# 0            http://dbpedia.org/resource/Carrot      51       Carrot
# 1          http://dbpedia.org/resource/Cucumber      47     Cucumber
# 2            http://dbpedia.org/resource/Tomato      43       Tomato
# 3            http://dbpedia.org/resource/Potato      19       Potato
# 4          http://dbpedia.org/resource/Broccoli      18          NaN
# 5          http://dbpedia.org/resource/Zucchini      17     Zucchini
# 6          http://dbpedia.org/resource/Eggplant      17     Eggplant
# 7       http://dbpedia.org/resource/Bell_pepper      14  Bell pepper
# 8           http://dbpedia.org/resource/Paprika      11      Paprika
# 9             http://dbpedia.org/resource/Onion      11        Onion
# 10      http://dbpedia.org/resource/Cauliflower      10  Cauliflower
# 11         http://dbpedia.org/resource/Mushroom       7          NaN
# 12          http://dbpedia.org/resource/Lettuce       6      Lettuce
# 13             http://dbpedia.org/resource/Bean       5         Bean
# 14          http://dbpedia.org/resource/Spinach       5      Spinach
# 15             http://dbpedia.org/resource/Leek       3         Leek
# 16          http://dbpedia.org/resource/Pumpkin       3      Pumpkin
# 17           http://dbpedia.org/resource/Turnip       2          NaN
# 18          http://dbpedia.org/resource/Avocado       2          NaN
# 19            http://dbpedia.org/resource/Apple       2          NaN
# 20         http://dbpedia.org/resource/Beetroot       2     Beetroot
# 21              http://dbpedia.org/resource/Pea       2          Pea
# 22           http://dbpedia.org/resource/Celery       2       Celery
# 23        http://dbpedia.org/resource/Asparagus       2          NaN
# 24          http://dbpedia.org/resource/Cabbage       2      Cabbage
# 25        http://dbpedia.org/resource/Artichoke       1          NaN
# 26             http://dbpedia.org/resource/Kale       1         Kale
# 27             http://dbpedia.org/resource/Leak       1          NaN
# 28  http://dbpedia.org/resource/Brussels_sprout       1          NaN
# 29           http://dbpedia.org/resource/Radish       1          NaN
# 30           http://dbpedia.org/resource/Banana       1          NaN
# 31            http://dbpedia.org/resource/Mango       1          NaN
# 32            http://dbpedia.org/resource/Grape       1          NaN
# 33           http://dbpedia.org/resource/Lentil       1       Lentil
# 34         http://dbpedia.org/resource/Capsicum       1          NaN
# 35           http://dbpedia.org/resource/Garlic       1       Garlic
# 36       http://dbpedia.org/resource/Green_bean       1   Green bean
#
#        degree  eigenvector   pagerank
# 0    3.533501     0.324573   3.479786
# 1    1.754923     0.317726   1.737238
# 2   11.570037     0.348644  11.056798
# 3   18.486729     0.345457  19.924285
# 4         NaN          NaN        NaN
# 5    0.305712    -0.190943   0.419327
# 6    2.150163     0.320709   2.069660
# 7    2.413656    -0.187573   2.235934
# 8    0.832698    -0.189405   0.755452
# 9   21.385152     0.359892  20.336650
# 10   0.635078    -0.191314   0.846759
# 11        NaN          NaN        NaN
# 12   1.623177     0.318867   1.803452
# 13   2.545402     0.324451   2.698506
# 14   1.557303     0.320849   1.545486
# 15   1.754923    -0.188739   1.721750
# 16   0.964444     0.316749   1.037156
# 17        NaN          NaN        NaN
# 18        NaN          NaN        NaN
# 19        NaN          NaN        NaN
# 20   0.239838    -0.191868   0.396472
# 21   1.227937     0.316105   1.320733
# 22   1.162064     0.319338   1.118965
# 23        NaN          NaN        NaN
# 24   3.006515    -0.187026   3.032548
# 25        NaN          NaN        NaN
# 26   0.371585    -0.189814   0.651543
# 27        NaN          NaN        NaN
# 28        NaN          NaN        NaN
# 29        NaN          NaN        NaN
# 30        NaN          NaN        NaN
# 31        NaN          NaN        NaN
# 32        NaN          NaN        NaN
# 33   0.898571     0.315954   0.943952
# 34        NaN          NaN        NaN
# 35  12.887502     0.344445  12.135952
# 36   0.700951     0.316936   0.731472

# %% [markdown]
# ### Fast food

# %%
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=1, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=5, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=10, opt='n')

precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=1, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=2, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=5, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'degree', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 1
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 5
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 3
# P@5: 0.6
# =====================================
# Precision at k=10 (n) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 10
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 4
# P@10: 0.4
# =====================================
# Precision at k=1 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 36
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 7
# P@1: 0.19444444444444445
# =====================================
# Precision at k=2 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 73
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 8
# P@2: 0.1095890410958904
# =====================================
# Precision at k=5 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 184
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 8
# P@5: 0.043478260869565216
# =====================================
# Precision at k=10 (p) for DEGREE
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 368
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 10
# P@10: 0.02717391304347826
# =====================================
#                                         resource  amount           name  \
# 0          http://dbpedia.org/resource/Hamburger     103      Hamburger
# 1              http://dbpedia.org/resource/Pizza      53          Pizza
# 2       http://dbpedia.org/resource/French_fries      51   French fries
# 3              http://dbpedia.org/resource/Kebab      23            NaN
# 4            http://dbpedia.org/resource/Hot_dog      17        Hot dog
# 5           http://dbpedia.org/resource/Sandwich      10       Sandwich
# 6               http://dbpedia.org/resource/Taco      10           Taco
# 7     http://dbpedia.org/resource/Chicken_nugget       8            NaN
# 8              http://dbpedia.org/resource/Sushi       5            NaN
# 9         http://dbpedia.org/resource/Currywurst       5            NaN
# 10      http://dbpedia.org/resource/Chicken_wing       4            NaN
# 11    http://dbpedia.org/resource/Fish_and_chips       4            NaN
# 12           http://dbpedia.org/resource/Falafel       2            NaN
# 13           http://dbpedia.org/resource/Burrito       2        Burrito
# 14      http://dbpedia.org/resource/Cheeseburger       2            NaN
# 15         http://dbpedia.org/resource/Milkshake       2            NaN
# 16             http://dbpedia.org/resource/Pasta       1            NaN
# 17            http://dbpedia.org/resource/Nachos       1         Nachos
# 18          http://dbpedia.org/resource/Ketwurst       1            NaN
# 19         http://dbpedia.org/resource/Ice_cream       1            NaN
# 20        http://dbpedia.org/resource/Onion_ring       1            NaN
# 21            http://dbpedia.org/resource/Samosa       1            NaN
# 22  http://dbpedia.org/resource/Chicken_sandwich       1            NaN
# 23         http://dbpedia.org/resource/Bratwurst       1            NaN
# 24       http://dbpedia.org/resource/Doner_kebab       1            NaN
# 25           http://dbpedia.org/resource/Poutine       1        Poutine
# 26     http://dbpedia.org/resource/Fried_chicken       1  Fried chicken
#
#        degree  eigenvector   pagerank
# 0    8.155695    -0.494157   8.493798
# 1   10.738978    -0.486140  12.520911
# 2    8.016058    -0.491335   8.299843
# 3         NaN          NaN        NaN
# 4    3.198583    -0.496974   3.368504
# 5   12.135347    -0.496772  12.470208
# 6    1.383303    -0.496993   1.546622
# 7         NaN          NaN        NaN
# 8         NaN          NaN        NaN
# 9         NaN          NaN        NaN
# 10        NaN          NaN        NaN
# 11        NaN          NaN        NaN
# 12        NaN          NaN        NaN
# 13   1.592759    -0.493990   1.813191
# 14        NaN          NaN        NaN
# 15        NaN          NaN        NaN
# 16        NaN          NaN        NaN
# 17   0.824756    -0.493997   0.898476
# 18        NaN          NaN        NaN
# 19        NaN          NaN        NaN
# 20        NaN          NaN        NaN
# 21        NaN          NaN        NaN
# 22        NaN          NaN        NaN
# 23        NaN          NaN        NaN
# 24        NaN          NaN        NaN
# 25   0.685119    -0.495920   0.723109
# 26   2.570217    -0.497007   2.787325

# %%
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=1, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=5, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=10, opt='n')

precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=1, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=2, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=5, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'eigenvector', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 1
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 5
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (n) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 10
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
# Precision at k=1 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 36
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=2 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 73
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@2: 0.0
# =====================================
# Precision at k=5 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 184
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@5: 0.0
# =====================================
# Precision at k=10 (p) for EIGENVECTOR
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 368
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@10: 0.0
# =====================================
#                                         resource  amount name  degree  \
# 0          http://dbpedia.org/resource/Hamburger     103  NaN     NaN
# 1              http://dbpedia.org/resource/Pizza      53  NaN     NaN
# 2       http://dbpedia.org/resource/French_fries      51  NaN     NaN
# 3              http://dbpedia.org/resource/Kebab      23  NaN     NaN
# 4            http://dbpedia.org/resource/Hot_dog      17  NaN     NaN
# 5           http://dbpedia.org/resource/Sandwich      10  NaN     NaN
# 6               http://dbpedia.org/resource/Taco      10  NaN     NaN
# 7     http://dbpedia.org/resource/Chicken_nugget       8  NaN     NaN
# 8              http://dbpedia.org/resource/Sushi       5  NaN     NaN
# 9         http://dbpedia.org/resource/Currywurst       5  NaN     NaN
# 10      http://dbpedia.org/resource/Chicken_wing       4  NaN     NaN
# 11    http://dbpedia.org/resource/Fish_and_chips       4  NaN     NaN
# 12           http://dbpedia.org/resource/Falafel       2  NaN     NaN
# 13           http://dbpedia.org/resource/Burrito       2  NaN     NaN
# 14      http://dbpedia.org/resource/Cheeseburger       2  NaN     NaN
# 15         http://dbpedia.org/resource/Milkshake       2  NaN     NaN
# 16             http://dbpedia.org/resource/Pasta       1  NaN     NaN
# 17            http://dbpedia.org/resource/Nachos       1  NaN     NaN
# 18          http://dbpedia.org/resource/Ketwurst       1  NaN     NaN
# 19         http://dbpedia.org/resource/Ice_cream       1  NaN     NaN
# 20        http://dbpedia.org/resource/Onion_ring       1  NaN     NaN
# 21            http://dbpedia.org/resource/Samosa       1  NaN     NaN
# 22  http://dbpedia.org/resource/Chicken_sandwich       1  NaN     NaN
# 23         http://dbpedia.org/resource/Bratwurst       1  NaN     NaN
# 24       http://dbpedia.org/resource/Doner_kebab       1  NaN     NaN
# 25           http://dbpedia.org/resource/Poutine       1  NaN     NaN
# 26     http://dbpedia.org/resource/Fried_chicken       1  NaN     NaN
#
#     eigenvector  pagerank
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN

# %%
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=1, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=5, opt='n')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=10, opt='n')

precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=1, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=2, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=5, opt='p')
precisionAtK(sv_fastfood, fastFood_resultNorm, 'pagerank', lot_nr=10, opt='p')
# Out:
# Precision at k=1 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 1
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 0
# P@1: 0.0
# =====================================
# Precision at k=5 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 5
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 3
# P@5: 0.6
# =====================================
# Precision at k=10 (n) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 10
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 4
# P@10: 0.4
# =====================================
# Precision at k=1 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 36
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 7
# P@1: 0.19444444444444445
# =====================================
# Precision at k=2 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 73
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 8
# P@2: 0.1095890410958904
# =====================================
# Precision at k=5 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 184
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 8
# P@5: 0.043478260869565216
# =====================================
# Precision at k=10 (p) for PAGERANK
# -------------------------------------
# Entries in the DBpedia category: 3687
# DBpedia entries taken: top 368
# Entries in the gold standard: 27
# -------------------------------------
# HITS: 9
# P@10: 0.024456521739130436
# =====================================
#                                         resource  amount           name  \
# 0          http://dbpedia.org/resource/Hamburger     103      Hamburger
# 1              http://dbpedia.org/resource/Pizza      53          Pizza
# 2       http://dbpedia.org/resource/French_fries      51   French fries
# 3              http://dbpedia.org/resource/Kebab      23            NaN
# 4            http://dbpedia.org/resource/Hot_dog      17        Hot dog
# 5           http://dbpedia.org/resource/Sandwich      10       Sandwich
# 6               http://dbpedia.org/resource/Taco      10           Taco
# 7     http://dbpedia.org/resource/Chicken_nugget       8            NaN
# 8              http://dbpedia.org/resource/Sushi       5            NaN
# 9         http://dbpedia.org/resource/Currywurst       5            NaN
# 10      http://dbpedia.org/resource/Chicken_wing       4            NaN
# 11    http://dbpedia.org/resource/Fish_and_chips       4            NaN
# 12           http://dbpedia.org/resource/Falafel       2            NaN
# 13           http://dbpedia.org/resource/Burrito       2        Burrito
# 14      http://dbpedia.org/resource/Cheeseburger       2            NaN
# 15         http://dbpedia.org/resource/Milkshake       2            NaN
# 16             http://dbpedia.org/resource/Pasta       1            NaN
# 17            http://dbpedia.org/resource/Nachos       1         Nachos
# 18          http://dbpedia.org/resource/Ketwurst       1            NaN
# 19         http://dbpedia.org/resource/Ice_cream       1            NaN
# 20        http://dbpedia.org/resource/Onion_ring       1            NaN
# 21            http://dbpedia.org/resource/Samosa       1            NaN
# 22  http://dbpedia.org/resource/Chicken_sandwich       1            NaN
# 23         http://dbpedia.org/resource/Bratwurst       1            NaN
# 24       http://dbpedia.org/resource/Doner_kebab       1            NaN
# 25           http://dbpedia.org/resource/Poutine       1            NaN
# 26     http://dbpedia.org/resource/Fried_chicken       1  Fried chicken
#
#        degree  eigenvector   pagerank
# 0    8.155695    -0.494157   8.493798
# 1   10.738978    -0.486140  12.520911
# 2    8.016058    -0.491335   8.299843
# 3         NaN          NaN        NaN
# 4    3.198583    -0.496974   3.368504
# 5   12.135347    -0.496772  12.470208
# 6    1.383303    -0.496993   1.546622
# 7         NaN          NaN        NaN
# 8         NaN          NaN        NaN
# 9         NaN          NaN        NaN
# 10        NaN          NaN        NaN
# 11        NaN          NaN        NaN
# 12        NaN          NaN        NaN
# 13   1.592759    -0.493990   1.813191
# 14        NaN          NaN        NaN
# 15        NaN          NaN        NaN
# 16        NaN          NaN        NaN
# 17   0.824756    -0.493997   0.898476
# 18        NaN          NaN        NaN
# 19        NaN          NaN        NaN
# 20        NaN          NaN        NaN
# 21        NaN          NaN        NaN
# 22        NaN          NaN        NaN
# 23        NaN          NaN        NaN
# 24        NaN          NaN        NaN
# 25        NaN          NaN        NaN
# 26   2.570217    -0.497007   2.787325

# %% [markdown]
# ## Normal distribution per category

# %%
normDist(musicGenres_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=11448.408583500346, pvalue=0.0)
# KstestResult(statistic=0.42331185817194567, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=18240.920855206765, pvalue=0.0)
# KstestResult(statistic=0.4859229774129339, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=11242.015006606698, pvalue=0.0)
# KstestResult(statistic=0.41890379074126616, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %%
normDist(potus_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=37.07071648803927, pvalue=8.916536557870695e-09)
# KstestResult(statistic=0.2844948885846291, pvalue=0.0007359048453400347) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=75.44237145355135, pvalue=4.148558208015599e-17)
# KstestResult(statistic=0.24318034268453162, pvalue=0.006227911802002413) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=37.57350120103277, pvalue=6.9345435717901226e-09)
# KstestResult(statistic=0.287576276498341, pvalue=0.0006186878718721136) [Kolmogorov-Smirnov-Test]

# %%
normDist(lakes_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=24841.472046441988, pvalue=0.0)
# KstestResult(statistic=0.3484717588713639, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=5999.98590510683, pvalue=0.0)
# KstestResult(statistic=0.22425901374085416, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=23891.88424263293, pvalue=0.0)
# KstestResult(statistic=0.3540552441182742, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %%
normDist(mountains_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=32534.773851115177, pvalue=0.0)
# KstestResult(statistic=0.4430192570979756, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=28994.487652744665, pvalue=0.0)
# KstestResult(statistic=0.3279219017576661, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=32414.46897952634, pvalue=0.0)
# KstestResult(statistic=0.44320703260004685, pvalue=0.0) [Kolmogorov-Smirnov-Test]

# %%
normDist(euCap_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=75.64567207608938, pvalue=3.747580916366938e-17)
# KstestResult(statistic=0.24929334665701874, pvalue=0.0024713948027295166) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=10.805982293413928, pvalue=0.00450309137110069)
# KstestResult(statistic=0.13276604581634205, pvalue=0.29282431428952865) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=73.45053797354096, pvalue=1.1230997553297713e-16)
# KstestResult(statistic=0.24462544491626848, pvalue=0.0031695285346560512) [Kolmogorov-Smirnov-Test]

# %%
normDist(euCou_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=42.9174358075871, pvalue=4.792887394434191e-10)
# KstestResult(statistic=0.29568441163410747, pvalue=0.00019014201790238142) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=49.20345386315511, pvalue=2.0682629312953554e-11)
# KstestResult(statistic=0.18496955704157425, pvalue=0.05326135388066376) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=46.92104494359943, pvalue=6.474773013459656e-11)
# KstestResult(statistic=0.2992634032068702, pvalue=0.00015138836667275468) [Kolmogorov-Smirnov-Test]

# %%
normDist(asCou_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=65.33821543910821, pvalue=6.486147022886163e-15)
# KstestResult(statistic=0.32149574222812904, pvalue=2.250832187978134e-05) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=41.52211352978797, pvalue=9.629142383037458e-10)
# KstestResult(statistic=0.2441224973339467, pvalue=0.002884259072044963) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=63.63897754867922, pvalue=1.5169511946636387e-14)
# KstestResult(statistic=0.29462320343985005, pvalue=0.00014266960842376596) [Kolmogorov-Smirnov-Test]

# %%
normDist(continents_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=37.01955506112853, pvalue=9.147570330558127e-09)
# KstestResult(statistic=0.35790098997361985, pvalue=0.03166722980303186) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=36.81151780045271, pvalue=1.0150337302611876e-08)
# KstestResult(statistic=0.36276036798607364, pvalue=0.028265762700198926) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=37.868572685767646, pvalue=5.983343312323509e-09)
# KstestResult(statistic=0.37321891816710406, pvalue=0.022006234558511743) [Kolmogorov-Smirnov-Test]
# /Users/kvnstz/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   "anyway, n=%i" % int(n))

# %%
normDist(africanAnimal_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=2654.5449351507914, pvalue=0.0)
# KstestResult(statistic=0.29440559659705656, pvalue=7.129866919631863e-106) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=1972.630276460582, pvalue=0.0)
# KstestResult(statistic=0.3014463843773041, pvalue=4.3622700737043096e-111) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=2454.4332968443114, pvalue=0.0)
# KstestResult(statistic=0.24710081946136114, pvalue=2.853561767138811e-74) [Kolmogorov-Smirnov-Test]

# %%
normDist(vegetables_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=3460.12474878811, pvalue=0.0)
# KstestResult(statistic=0.33764675069076, pvalue=6.708083957705485e-198) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=4959.780795073114, pvalue=0.0)
# KstestResult(statistic=0.42319174646130797, pvalue=8.74237866e-316) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=3467.009045159943, pvalue=0.0)
# KstestResult(statistic=0.32410607758058874, pvalue=5.535387831968465e-182) [Kolmogorov-Smirnov-Test]

# %%
normDist(fastFood_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=9410.763697699049, pvalue=0.0)
# KstestResult(statistic=0.28379180214698924, pvalue=2.397580459470729e-258) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=1237.7262278458475, pvalue=1.7028036397435766e-269)
# KstestResult(statistic=0.4240083909459136, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=9131.458161686998, pvalue=0.0)
# KstestResult(statistic=0.25196360058418205, pvalue=9.750110952548338e-204) [Kolmogorov-Smirnov-Test]

# %%
normDist(birds_resultNorm)
# Out:
# Normal distribution for Degree Centrality
# ----------------------
# NormaltestResult(statistic=7824.489189027847, pvalue=0.0)
# KstestResult(statistic=0.3728343921724312, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for Eigenvector Centrality
# ----------------------
# NormaltestResult(statistic=7868.01699751277, pvalue=0.0)
# KstestResult(statistic=0.49621121615157715, pvalue=0.0) [Kolmogorov-Smirnov-Test]
# ======================
# Normal distribution for PageRank
# ----------------------
# NormaltestResult(statistic=7889.86346765612, pvalue=0.0)
# KstestResult(statistic=0.3561875745550973, pvalue=0.0) [Kolmogorov-Smirnov-Test]
