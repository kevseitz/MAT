# %%
# importing packages
import pandas as pd
#from lxml import etree
import os.path, time
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G.add_node('Science Fiction')
G.add_node('The Matrix')

# %%
nx.draw(G, with_labels = True)

# %%
import matplotlib.pyplot as plt
import networkx as nx

edges = [['The Matrix', 'Neo'], ['The Matrix', 'Science Fiction'], ['Science Fiction', 'Star Trek'], ['Avery Brooks', 'Star Trek'], ['Avery Brooks', 'Captain Sisko']]
G = nx.Graph()
G.add_edges_from(edges)
pos = nx.spring_layout(G)
plt.figure()
nx.draw(
    G, pos, edge_color='black', width=1, linewidths=1,
    node_size=500, node_color='pink', alpha=0.9,
    labels={node: node for node in G.nodes()}
)
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels={('The Matrix', 'Neo'): 'characterIn', 
                 ('The Matrix', 'Science Fiction'): 'genre', 
                 ('Avery Brooks', 'Star Trek'): 'starredIn',
                 ('Avery Brooks', 'Captain Sisko'): 'played',
                 ('Captain Sisko', 'Star Trek'): 'characterIn',
                 ('Science Fiction', 'Star Trek'): 'genre'},
    font_color='red'
)
plt.axis('off')
plt.show()

# %%
G = nx.DiGraph()

G.add_edges_from([('The Matrix', 'Science Fiction'), (1, 3), (2, 3)])

pos = nx.spring_layout(G)

nx.draw_networkx(G, pos)

edge_labels = dict([((n1, n2), f'genre')
                    for n1, n2 in G.edges])

nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.show()

# %%
import pygraphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-e9ec173dab0d> in <module>
# ----> 1 import pygraphviz
#
# ModuleNotFoundError: No module named 'pygraphviz'

# %%
import pygraphviz as pgv

# strict (no parallel edges)
# digraph
# with attribute rankdir set to 'LR'
A = pgv.AGraph(directed=True, strict=True, rankdir="LR")
# add node 1 with color red
A.add_node('The Matrix', color="red")
A.add_node(5, color="blue")
# add some edges
A.add_edge(1, 2, color="green")
A.add_edge(2, 3)
A.add_edge(1, 3)
A.add_edge(3, 4)
A.add_edge(3, 5)
A.add_edge(3, 6)
A.add_edge(4, 6)
# adjust a graph parameter
A.graph_attr["epsilon"] = "0.001"
print(A.string())  # print dot file to standard output
A.layout("dot")  # layout with dot
A.draw("foo.png")  # write to file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-2d7183c4e614> in <module>
# ----> 1 import pygraphviz as pgv
#       2
#       3 # strict (no parallel edges)
#       4 # digraph
#       5 # with attribute rankdir set to 'LR'
#
# ModuleNotFoundError: No module named 'pygraphviz'
